# %%
import pandas as pd

df = pd.read_excel("PAP 02 data for TAS204040 overall data for model building - 2.xlsx")

# %%
df.shape
# Out:
# (10850, 51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10850 entries, 0 to 10849
# Data columns (total 51 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    10850 non-null  datetime64[ns]
#  1   Weigh feeder rate AJD2706A-WIC.PV       10850 non-null  float64
#  2   Weigh feeder rate BJD2706B-WIC.PV       10850 non-null  float64
#  3   Ball mill ampsPA2729A-AI                10850 non-null  float64
#  4   BALL MILL VENT SYS TEMPTI2705.PV        10850 non-null  float64
#  5   BALL MILL VENT FAN CURRENTGB2705-AI.PV  10850 non-null  float64
#  6   BAG FLTR SUC PRESSUREPI2705A.PV         10850 non-null  float64
#  7   FAN SUC PRESSUREPI2705C.PV              10850 non-null  float64
#  8   SCREW CONV - CURRENTJD2709-AI.PV        10850 non-null  float64
#  9   BUCKET ELEVATOR CURRENTJD2710-AI.PV     10850 non-null  float64
#  10  WEIGH FDR A FEED RATEJD2715A-WIC.PV     10850 non-null  float64
#  11  WEIGH FDR B FEED RATEJD2715B-WIC.PV     10850 non-null  float64
#  12  H2SO4 TO ATTACK RCT A FLOWFIC2802.PV    10850 non-null  float64
#  13  H2SO4 TO ATTACK RCT B FLOWFIC2803.PV    10850 non-null  float64
#  14  RECYCL ACD ATTACK RCT A FLOWFIC2804.PV  10850 non-null  float64
#  15  RECYCL ACD ATTACK RCT B FLOWFIC2805.PV  10850 non-null  object
#  16  ATTACK AGTR A CURRENTGD2801A-AI.PV      10850 non-null  float64
#  17  ATTACK AGTR B CURRENTGD2801B-AI.PV      10850 non-null  float64
#  18  ATTACK AGTR C CURRENTGD2801C-AI.PV      10850 non-null  float64
#  19  ATTACK AGTR D CURRENTGD2801D-AI.PV      10850 non-null  float64
#  20  ATTACK RCT B TEMPTI2801B.PV             10850 non-null  float64
#  21  ATTACK RCT D TEMPTI2801D.PV             10850 non-null  float64
#  22  Filter SPGPA2_FILSPG                    10850 non-null  float64
#  23  Slurry SPGPA2_SLURRYSPG                 10850 non-null  float64
#  24  Free AcidPA2_FREEACID                   10850 non-null  float64
#  25  Reactor SolidsREACT-SOLIDS.PV           10850 non-null  float64
#  26  NEW DIGESTION TANK LEVELLI2802.PV       10850 non-null  float64
#  27  LOW LVL FLASH COOLER VACUUMPIC2801.PV   10850 non-null  float64
#  28  TD LLFC I/L & O/L TEMPTDY2806.PV        10850 non-null  float64
#  29  Slurry FlowFIC2902                      10850 non-null  float64
#  30  LLFC CIRC PMP CURRENTGA2801-AI.PV       10850 non-null  float64
#  31  LLFC CIRC PMP SPEEDGA2801-SI.PV         10850 non-null  float64
#  32  Scrubber FanGB2801-AI                   10850 non-null  float64
#  33  HBF Vacuum PIC2917                      10850 non-null  float64
#  34  HBF CurrentFD2901-AI                    10850 non-null  float64
#  35  HBF SpeedFD2901-SI                      10850 non-null  float64
#  36  HBF support fanGB2902-AI                10850 non-null  object
#  37  CLOTH TRACK BELLOW 1 PRESSUREPI2902     10850 non-null  float64
#  38  CLOTH TRACK BELLOW 2 PRESSUREPI2903     10850 non-null  float64
#  39  CLOTH WASH PMP DISCH FLOWFI2909         10850 non-null  float64
#  40  Cakewash flowFIC2908                    10850 non-null  float64
#  41  Weak wash flowFIC2907                   10850 non-null  object
#  42  Strong wash flowFIC2906                 10850 non-null  float64
#  43  Return acid flowFIC2905                 10850 non-null  float64
#  44  Product acid flowFIC2904                10850 non-null  float64
#  45  HBF Vacuum pump ampsGB2901-AI           10850 non-null  float64
#  46  Cake wash temperatureTI2908             10850 non-null  object
#  47  No 1 filtrate %P2O5                     10850 non-null  float64
#  48  No 1 filtrate Sp Gr                     10850 non-null  float64
#  49  No 1 filtrate FREEACID                  10850 non-null  float64
#  50  Gypsum TP2O5 loss                       10850 non-null  float64
# dtypes: datetime64[ns](1), float64(46), object(4)
# memory usage: 4.2+ MB

# %%
object_cols = df.select_dtypes(include='object').columns
print(object_cols)
# Out:
# Index(['RECYCL ACD ATTACK RCT B FLOWFIC2805.PV', 'HBF support fanGB2902-AI',
#        'Weak wash flowFIC2907', 'Cake wash temperatureTI2908'],
#       dtype='object')

# %%
for col in object_cols:
    print("\nColumn:", col)
    print(df[col].head(10))
# Out:
# Column: RECYCL ACD ATTACK RCT B FLOWFIC2805.PV
# 0     155.86059
# 1    155.729849
# 2    156.217867
# 3    155.777613
# 4    156.429135
# 5    156.213995
# 6    155.968487
# 7    156.133444
# 8    156.044965
# 9    156.277248
# Name: RECYCL ACD ATTACK RCT B FLOWFIC2805.PV, dtype: object
#
# Column: HBF support fanGB2902-AI
# 0    28.701143
# 1    28.552285
# 2    28.706453
# 3    28.695628
# 4    28.770045
# 5    28.707615
# 6    28.604572
# 7     28.69698
# 8    28.612165
# 9    28.707431
# Name: HBF support fanGB2902-AI, dtype: object
#
# Column: Weak wash flowFIC2907
# 0     -0.668228
# 1     -0.744572
# 2     -0.631908
# 3     -0.529602
# 4     -0.629929
# 5     15.062498
# 6    190.494664
# 7    196.027116
# 8    196.036193
# 9    196.032499
# Name: Weak wash flowFIC2907, dtype: object
#
# Column: Cake wash temperatureTI2908
# 0     46.46743
# 1    46.466528
# 2    46.636018
# 3    46.747643
# 4     46.80054
# 5    46.910492
# 6     47.01317
# 7     47.03064
# 8    47.023056
# 9    47.101363
# Name: Cake wash temperatureTI2908, dtype: object

# %%
object_cols = df.select_dtypes(include='object').columns
print(object_cols)
# Out:
# Index(['RECYCL ACD ATTACK RCT B FLOWFIC2805.PV', 'HBF support fanGB2902-AI',
#        'Weak wash flowFIC2907', 'Cake wash temperatureTI2908'],
#       dtype='object')

# %%
for col in object_cols:
    print("\n", col)
    print(df[col].head(10))
# Out:
#  RECYCL ACD ATTACK RCT B FLOWFIC2805.PV
# 0     155.86059
# 1    155.729849
# 2    156.217867
# 3    155.777613
# 4    156.429135
# 5    156.213995
# 6    155.968487
# 7    156.133444
# 8    156.044965
# 9    156.277248
# Name: RECYCL ACD ATTACK RCT B FLOWFIC2805.PV, dtype: object
#
#  HBF support fanGB2902-AI
# 0    28.701143
# 1    28.552285
# 2    28.706453
# 3    28.695628
# 4    28.770045
# 5    28.707615
# 6    28.604572
# 7     28.69698
# 8    28.612165
# 9    28.707431
# Name: HBF support fanGB2902-AI, dtype: object
#
#  Weak wash flowFIC2907
# 0     -0.668228
# 1     -0.744572
# 2     -0.631908
# 3     -0.529602
# 4     -0.629929
# 5     15.062498
# 6    190.494664
# 7    196.027116
# 8    196.036193
# 9    196.032499
# Name: Weak wash flowFIC2907, dtype: object
#
#  Cake wash temperatureTI2908
# 0     46.46743
# 1    46.466528
# 2    46.636018
# 3    46.747643
# 4     46.80054
# 5    46.910492
# 6     47.01317
# 7     47.03064
# 8    47.023056
# 9    47.101363
# Name: Cake wash temperatureTI2908, dtype: object

# %%
for col in object_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10850 entries, 0 to 10849
# Data columns (total 51 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    10850 non-null  datetime64[ns]
#  1   Weigh feeder rate AJD2706A-WIC.PV       10850 non-null  float64
#  2   Weigh feeder rate BJD2706B-WIC.PV       10850 non-null  float64
#  3   Ball mill ampsPA2729A-AI                10850 non-null  float64
#  4   BALL MILL VENT SYS TEMPTI2705.PV        10850 non-null  float64
#  5   BALL MILL VENT FAN CURRENTGB2705-AI.PV  10850 non-null  float64
#  6   BAG FLTR SUC PRESSUREPI2705A.PV         10850 non-null  float64
#  7   FAN SUC PRESSUREPI2705C.PV              10850 non-null  float64
#  8   SCREW CONV - CURRENTJD2709-AI.PV        10850 non-null  float64
#  9   BUCKET ELEVATOR CURRENTJD2710-AI.PV     10850 non-null  float64
#  10  WEIGH FDR A FEED RATEJD2715A-WIC.PV     10850 non-null  float64
#  11  WEIGH FDR B FEED RATEJD2715B-WIC.PV     10850 non-null  float64
#  12  H2SO4 TO ATTACK RCT A FLOWFIC2802.PV    10850 non-null  float64
#  13  H2SO4 TO ATTACK RCT B FLOWFIC2803.PV    10850 non-null  float64
#  14  RECYCL ACD ATTACK RCT A FLOWFIC2804.PV  10850 non-null  float64
#  15  RECYCL ACD ATTACK RCT B FLOWFIC2805.PV  10849 non-null  float64
#  16  ATTACK AGTR A CURRENTGD2801A-AI.PV      10850 non-null  float64
#  17  ATTACK AGTR B CURRENTGD2801B-AI.PV      10850 non-null  float64
#  18  ATTACK AGTR C CURRENTGD2801C-AI.PV      10850 non-null  float64
#  19  ATTACK AGTR D CURRENTGD2801D-AI.PV      10850 non-null  float64
#  20  ATTACK RCT B TEMPTI2801B.PV             10850 non-null  float64
#  21  ATTACK RCT D TEMPTI2801D.PV             10850 non-null  float64
#  22  Filter SPGPA2_FILSPG                    10850 non-null  float64
#  23  Slurry SPGPA2_SLURRYSPG                 10850 non-null  float64
#  24  Free AcidPA2_FREEACID                   10850 non-null  float64
#  25  Reactor SolidsREACT-SOLIDS.PV           10850 non-null  float64
#  26  NEW DIGESTION TANK LEVELLI2802.PV       10850 non-null  float64
#  27  LOW LVL FLASH COOLER VACUUMPIC2801.PV   10850 non-null  float64
#  28  TD LLFC I/L & O/L TEMPTDY2806.PV        10850 non-null  float64
#  29  Slurry FlowFIC2902                      10850 non-null  float64
#  30  LLFC CIRC PMP CURRENTGA2801-AI.PV       10850 non-null  float64
#  31  LLFC CIRC PMP SPEEDGA2801-SI.PV         10850 non-null  float64
#  32  Scrubber FanGB2801-AI                   10850 non-null  float64
#  33  HBF Vacuum PIC2917                      10850 non-null  float64
#  34  HBF CurrentFD2901-AI                    10850 non-null  float64
#  35  HBF SpeedFD2901-SI                      10850 non-null  float64
#  36  HBF support fanGB2902-AI                10844 non-null  float64
#  37  CLOTH TRACK BELLOW 1 PRESSUREPI2902     10850 non-null  float64
#  38  CLOTH TRACK BELLOW 2 PRESSUREPI2903     10850 non-null  float64
#  39  CLOTH WASH PMP DISCH FLOWFI2909         10850 non-null  float64
#  40  Cakewash flowFIC2908                    10850 non-null  float64
#  41  Weak wash flowFIC2907                   10848 non-null  float64
#  42  Strong wash flowFIC2906                 10850 non-null  float64
#  43  Return acid flowFIC2905                 10850 non-null  float64
#  44  Product acid flowFIC2904                10850 non-null  float64
#  45  HBF Vacuum pump ampsGB2901-AI           10850 non-null  float64
#  46  Cake wash temperatureTI2908             10847 non-null  float64
#  47  No 1 filtrate %P2O5                     10850 non-null  float64
#  48  No 1 filtrate Sp Gr                     10850 non-null  float64
#  49  No 1 filtrate FREEACID                  10850 non-null  float64
#  50  Gypsum TP2O5 loss                       10850 non-null  float64
# dtypes: datetime64[ns](1), float64(50)
# memory usage: 4.2 MB

# %%
df.head()
# Out:
#                  Date  Weigh feeder rate AJD2706A-WIC.PV  \
# 0 2024-08-16 00:00:00                          21.003220
# 1 2024-08-16 00:01:00                          20.991936
# 2 2024-08-16 00:02:00                          20.989039
# 3 2024-08-16 00:03:00                          20.960600
# 4 2024-08-16 00:04:00                          20.980026
#
#    Weigh feeder rate BJD2706B-WIC.PV  Ball mill ampsPA2729A-AI  \
# 0                          94.161446                 82.350600
# 1                          94.172357                 81.727671
# 2                          94.204102                 82.314959
# 3                          94.173983                 81.975168
# 4                          94.185356                 82.028157
#
#    BALL MILL VENT SYS TEMPTI2705.PV  BALL MILL VENT FAN CURRENTGB2705-AI.PV  \
# 0                         41.524604                               65.222143
# 1                         41.534792                               65.320041
# 2                         41.535210                               65.340228
# 3                         41.535314                               65.543949
# 4                         41.522601                               65.632107
#
#    BAG FLTR SUC PRESSUREPI2705A.PV  FAN SUC PRESSUREPI2705C.PV  \
# 0                       -74.123647                 -532.283019
# 1                       -73.535191                 -532.324575
# 2                       -74.640755                 -533.264507
# 3                       -73.477263                 -532.665851
# 4                       -73.671676                 -532.298998
#
#    SCREW CONV - CURRENTJD2709-AI.PV  BUCKET ELEVATOR CURRENTJD2710-AI.PV  ...  \
# 0                         27.702873                            17.937982  ...
# 1                         27.728852                            17.911349  ...
# 2                         27.724475                            17.847356  ...
# 3                         27.775387                            17.998736  ...
# 4                         27.883254                            17.982801  ...
#
#    Weak wash flowFIC2907  Strong wash flowFIC2906  Return acid flowFIC2905  \
# 0              -0.668228               140.062360               303.501065
# 1              -0.744572               140.788966               300.159550
# 2              -0.631908               141.233847               302.763613
# 3              -0.529602               140.432623               304.755494
# 4              -0.629929               140.395813               302.064553
#
#    Product acid flowFIC2904  HBF Vacuum pump ampsGB2901-AI  \
# 0                122.739652                      19.667590
# 1                116.545784                      19.378857
# 2                110.251764                      19.749524
# 3                124.951108                      19.395786
# 4                131.859675                      19.709130
#
#   Cake wash temperatureTI2908  No 1 filtrate %P2O5  No 1 filtrate Sp Gr  \
# 0                    46.46743                24.93                1.295
# 1                   46.466528                24.93                1.295
# 2                   46.636018                24.93                1.295
# 3                   46.747643                24.93                1.295
# 4                    46.80054                24.93                1.295
#
#    No 1 filtrate FREEACID  Gypsum TP2O5 loss
# 0                     2.3               1.36
# 1                     2.3               1.36
# 2                     2.3               1.36
# 3                     2.3               1.36
# 4                     2.3               1.36
#
# [5 rows x 51 columns]

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Weigh feeder rate AJD2706A-WIC.PV         0
# Weigh feeder rate BJD2706B-WIC.PV         0
# Ball mill ampsPA2729A-AI                  0
# BALL MILL VENT SYS TEMPTI2705.PV          0
# BALL MILL VENT FAN CURRENTGB2705-AI.PV    0
# BAG FLTR SUC PRESSUREPI2705A.PV           0
# FAN SUC PRESSUREPI2705C.PV                0
# SCREW CONV - CURRENTJD2709-AI.PV          0
# BUCKET ELEVATOR CURRENTJD2710-AI.PV       0
# WEIGH FDR A FEED RATEJD2715A-WIC.PV       0
# WEIGH FDR B FEED RATEJD2715B-WIC.PV       0
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV      0
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV      0
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV    0
# RECYCL ACD ATTACK RCT B FLOWFIC2805.PV    1
# ATTACK AGTR A CURRENTGD2801A-AI.PV        0
# ATTACK AGTR B CURRENTGD2801B-AI.PV        0
# ATTACK AGTR C CURRENTGD2801C-AI.PV        0
# ATTACK AGTR D CURRENTGD2801D-AI.PV        0
# ATTACK RCT B TEMPTI2801B.PV               0
# ATTACK RCT D TEMPTI2801D.PV               0
# Filter SPGPA2_FILSPG                      0
# Slurry SPGPA2_SLURRYSPG                   0
# Free AcidPA2_FREEACID                     0
# Reactor SolidsREACT-SOLIDS.PV             0
# NEW DIGESTION TANK LEVELLI2802.PV         0
# LOW LVL FLASH COOLER VACUUMPIC2801.PV     0
# TD LLFC I/L & O/L TEMPTDY2806.PV          0
# Slurry FlowFIC2902                        0
# LLFC CIRC PMP CURRENTGA2801-AI.PV         0
# LLFC CIRC PMP SPEEDGA2801-SI.PV           0
# Scrubber FanGB2801-AI                     0
# HBF Vacuum PIC2917                        0
# HBF CurrentFD2901-AI                      0
# HBF SpeedFD2901-SI                        0
# HBF support fanGB2902-AI                  6
# CLOTH TRACK BELLOW 1 PRESSUREPI2902       0
# CLOTH TRACK BELLOW 2 PRESSUREPI2903       0
# CLOTH WASH PMP DISCH FLOWFI2909           0
# Cakewash flowFIC2908                      0
# Weak wash flowFIC2907                     2
# Strong wash flowFIC2906                   0
# Return acid flowFIC2905                   0
# Product acid flowFIC2904                  0
# HBF Vacuum pump ampsGB2901-AI             0
# Cake wash temperatureTI2908               3
# No 1 filtrate %P2O5                       0
# No 1 filtrate Sp Gr                       0
# No 1 filtrate FREEACID                    0
# Gypsum TP2O5 loss                         0
# dtype: int64

# %%
df = df.dropna()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    print(col, (df[col] < 0).sum())
# Out:
# Weigh feeder rate AJD2706A-WIC.PV 0
# Weigh feeder rate BJD2706B-WIC.PV 0
# Ball mill ampsPA2729A-AI 118
# BALL MILL VENT SYS TEMPTI2705.PV 0
# BALL MILL VENT FAN CURRENTGB2705-AI.PV 0
# BAG FLTR SUC PRESSUREPI2705A.PV 10850
# FAN SUC PRESSUREPI2705C.PV 10850
# SCREW CONV - CURRENTJD2709-AI.PV 36
# BUCKET ELEVATOR CURRENTJD2710-AI.PV 0
# WEIGH FDR A FEED RATEJD2715A-WIC.PV 13
# WEIGH FDR B FEED RATEJD2715B-WIC.PV 530
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV 0
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV 155
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV 5863
# ATTACK AGTR A CURRENTGD2801A-AI.PV 0
# ATTACK AGTR B CURRENTGD2801B-AI.PV 0
# ATTACK AGTR C CURRENTGD2801C-AI.PV 0
# ATTACK AGTR D CURRENTGD2801D-AI.PV 0
# ATTACK RCT B TEMPTI2801B.PV 0
# ATTACK RCT D TEMPTI2801D.PV 0
# Filter SPGPA2_FILSPG 0
# Slurry SPGPA2_SLURRYSPG 0
# Free AcidPA2_FREEACID 0
# Reactor SolidsREACT-SOLIDS.PV 0
# NEW DIGESTION TANK LEVELLI2802.PV 0
# LOW LVL FLASH COOLER VACUUMPIC2801.PV 0
# TD LLFC I/L & O/L TEMPTDY2806.PV 52
# Slurry FlowFIC2902 0
# LLFC CIRC PMP CURRENTGA2801-AI.PV 0
# LLFC CIRC PMP SPEEDGA2801-SI.PV 0
# Scrubber FanGB2801-AI 0
# HBF Vacuum PIC2917 10850
# HBF CurrentFD2901-AI 190
# HBF SpeedFD2901-SI 0
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 52
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 3875
# CLOTH WASH PMP DISCH FLOWFI2909 0
# Cakewash flowFIC2908 95
# Strong wash flowFIC2906 0
# Return acid flowFIC2905 6
# Product acid flowFIC2904 0
# HBF Vacuum pump ampsGB2901-AI 15
# No 1 filtrate %P2O5 0
# No 1 filtrate Sp Gr 0
# No 1 filtrate FREEACID 0
# Gypsum TP2O5 loss 0

# %%
for col in numeric_cols:
    df = df[df[col] >= 0]

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    print(col, (df[col] < 0).sum())
# Out:
# Weigh feeder rate AJD2706A-WIC.PV 0
# Weigh feeder rate BJD2706B-WIC.PV 0
# Ball mill ampsPA2729A-AI 0
# BALL MILL VENT SYS TEMPTI2705.PV 0
# BALL MILL VENT FAN CURRENTGB2705-AI.PV 0
# BAG FLTR SUC PRESSUREPI2705A.PV 0
# FAN SUC PRESSUREPI2705C.PV 0
# SCREW CONV - CURRENTJD2709-AI.PV 0
# BUCKET ELEVATOR CURRENTJD2710-AI.PV 0
# WEIGH FDR A FEED RATEJD2715A-WIC.PV 0
# WEIGH FDR B FEED RATEJD2715B-WIC.PV 0
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV 0
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV 0
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV 0
# RECYCL ACD ATTACK RCT B FLOWFIC2805.PV 0
# ATTACK AGTR A CURRENTGD2801A-AI.PV 0
# ATTACK AGTR B CURRENTGD2801B-AI.PV 0
# ATTACK AGTR C CURRENTGD2801C-AI.PV 0
# ATTACK AGTR D CURRENTGD2801D-AI.PV 0
# ATTACK RCT B TEMPTI2801B.PV 0
# ATTACK RCT D TEMPTI2801D.PV 0
# Filter SPGPA2_FILSPG 0
# Slurry SPGPA2_SLURRYSPG 0
# Free AcidPA2_FREEACID 0
# Reactor SolidsREACT-SOLIDS.PV 0
# NEW DIGESTION TANK LEVELLI2802.PV 0
# LOW LVL FLASH COOLER VACUUMPIC2801.PV 0
# TD LLFC I/L & O/L TEMPTDY2806.PV 0
# Slurry FlowFIC2902 0
# LLFC CIRC PMP CURRENTGA2801-AI.PV 0
# LLFC CIRC PMP SPEEDGA2801-SI.PV 0
# Scrubber FanGB2801-AI 0
# HBF Vacuum PIC2917 0
# HBF CurrentFD2901-AI 0
# HBF SpeedFD2901-SI 0
# HBF support fanGB2902-AI 0
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 0
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 0
# CLOTH WASH PMP DISCH FLOWFI2909 0
# Cakewash flowFIC2908 0
# Weak wash flowFIC2907 0
# Strong wash flowFIC2906 0
# Return acid flowFIC2905 0
# Product acid flowFIC2904 0
# HBF Vacuum pump ampsGB2901-AI 0
# Cake wash temperatureTI2908 0
# No 1 filtrate %P2O5 0
# No 1 filtrate Sp Gr 0
# No 1 filtrate FREEACID 0
# Gypsum TP2O5 loss 0

# %%
df.describe()
# Out:
#                                 Date  Weigh feeder rate AJD2706A-WIC.PV  \
# count                          10850                       10850.000000
# mean   2024-08-20 14:57:27.069124608                          18.218613
# min              2024-08-16 00:00:00                           0.038591
# 25%              2024-08-17 21:12:15                          18.277518
# 50%              2024-08-20 21:34:30                          19.941469
# 75%              2024-08-22 18:46:45                          20.429159
# max              2024-08-24 23:59:00                          22.031294
# std                              NaN                           4.897770
#
#        Weigh feeder rate BJD2706B-WIC.PV  Ball mill ampsPA2729A-AI  \
# count                       10850.000000              10850.000000
# mean                           81.536462                 81.358197
# min                             0.007945                 -0.008053
# 25%                            82.009682                 82.170628
# 50%                            89.715141                 82.790957
# 75%                            91.939978                 83.815934
# max                            98.132406                 94.943709
# std                            22.686978                 13.997679
#
#        BALL MILL VENT SYS TEMPTI2705.PV  \
# count                      10850.000000
# mean                          42.919597
# min                           31.353878
# 25%                           41.969537
# 50%                           42.528168
# 75%                           43.453985
# max                           52.741472
# std                            2.340764
#
#        BALL MILL VENT FAN CURRENTGB2705-AI.PV  \
# count                            10850.000000
# mean                                63.543882
# min                                  0.037368
# 25%                                 64.301376
# 50%                                 65.726765
# 75%                                 67.696170
# max                                 84.242000
# std                                 13.769345
#
#        BAG FLTR SUC PRESSUREPI2705A.PV  FAN SUC PRESSUREPI2705C.PV  \
# count                     10850.000000                10850.000000
# mean                        -75.283117                 -503.910204
# min                        -251.365198                 -537.845151
# 25%                         -87.042962                 -532.351364
# 50%                         -66.252291                 -530.267273
# 75%                         -53.233668                 -525.803421
# max                          -0.375329                   -0.018210
# std                          39.370476                  105.939630
#
#        SCREW CONV - CURRENTJD2709-AI.PV  BUCKET ELEVATOR CURRENTJD2710-AI.PV  \
# count                      10850.000000                         10850.000000
# mean                          27.745874                            18.253557
# min                           -0.002400                             0.006914
# 25%                           27.457412                            16.612864
# 50%                           27.895842                            17.159450
# 75%                           28.244891                            18.662703
# max                           29.032222                            32.109132
# std                            1.722521                             3.048925
#
#        ...  CLOTH WASH PMP DISCH FLOWFI2909  Cakewash flowFIC2908  \
# count  ...                     10850.000000          10850.000000
# mean   ...                        33.783098            131.952145
# min    ...                         2.876617             -0.018725
# 25%    ...                        31.746428            126.336199
# 50%    ...                        33.830451            135.138491
# 75%    ...                        36.785032            144.982078
# max    ...                        43.946866            202.822852
# std    ...                         4.649628             27.199673
#
#        Strong wash flowFIC2906  Return acid flowFIC2905  \
# count             10850.000000             10850.000000
# mean                130.068985               287.305677
# min                   0.047687                -6.733179
# 25%                 129.856343               289.078907
# 50%                 139.554366               300.197862
# 75%                 140.173121               308.271836
# max                 225.547049               389.155414
# std                  25.139932                57.676222
#
#        Product acid flowFIC2904  HBF Vacuum pump ampsGB2901-AI  \
# count              10850.000000                   10850.000000
# mean                 101.984886                      20.250859
# min                    0.000854                      -0.000982
# 25%                   86.142700                      20.070571
# 50%                  113.051287                      20.632760
# 75%                  119.671004                      21.034797
# max                  136.549529                      22.091710
# std                   28.957857                       2.315226
#
#        No 1 filtrate %P2O5  No 1 filtrate Sp Gr  No 1 filtrate FREEACID  \
# count         10850.000000         10850.000000            10850.000000
# mean             25.362623             1.304243                2.481956
# min              22.770000             1.262000                1.850000
# 25%              25.120000             1.298000                2.380000
# 50%              25.540000             1.306000                2.490000
# 75%              25.780000             1.313000                2.570000
# max              26.680000             1.328000                2.850000
# std               0.705203             0.013567                0.185453
#
#        Gypsum TP2O5 loss
# count       10850.000000
# mean            1.259808
# min             0.970000
# 25%             1.110000
# 50%             1.230000
# 75%             1.320000
# max             2.270000
# std             0.220830
#
# [8 rows x 47 columns]

# %%
df.shape
# Out:
# (10850, 51)

# %%
df.std(numeric_only=True)
# Out:
# Weigh feeder rate AJD2706A-WIC.PV           4.897770
# Weigh feeder rate BJD2706B-WIC.PV          22.686978
# Ball mill ampsPA2729A-AI                   13.997679
# BALL MILL VENT SYS TEMPTI2705.PV            2.340764
# BALL MILL VENT FAN CURRENTGB2705-AI.PV     13.769345
# BAG FLTR SUC PRESSUREPI2705A.PV            39.370476
# FAN SUC PRESSUREPI2705C.PV                105.939630
# SCREW CONV - CURRENTJD2709-AI.PV            1.722521
# BUCKET ELEVATOR CURRENTJD2710-AI.PV         3.048925
# WEIGH FDR A FEED RATEJD2715A-WIC.PV        11.321547
# WEIGH FDR B FEED RATEJD2715B-WIC.PV        13.623983
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV        4.148573
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV        5.210844
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV     80.183356
# ATTACK AGTR A CURRENTGD2801A-AI.PV          3.704845
# ATTACK AGTR B CURRENTGD2801B-AI.PV          3.924226
# ATTACK AGTR C CURRENTGD2801C-AI.PV          3.907795
# ATTACK AGTR D CURRENTGD2801D-AI.PV          4.441574
# ATTACK RCT B TEMPTI2801B.PV                 2.267038
# ATTACK RCT D TEMPTI2801D.PV                 2.148005
# Filter SPGPA2_FILSPG                        0.009492
# Slurry SPGPA2_SLURRYSPG                     0.015162
# Free AcidPA2_FREEACID                       0.200874
# Reactor SolidsREACT-SOLIDS.PV               1.789665
# NEW DIGESTION TANK LEVELLI2802.PV           5.483078
# LOW LVL FLASH COOLER VACUUMPIC2801.PV      19.709274
# TD LLFC I/L & O/L TEMPTDY2806.PV            1.047016
# Slurry FlowFIC2902                         66.352507
# LLFC CIRC PMP CURRENTGA2801-AI.PV           2.044266
# LLFC CIRC PMP SPEEDGA2801-SI.PV            15.542916
# Scrubber FanGB2801-AI                      10.663154
# HBF Vacuum PIC2917                         64.370028
# HBF CurrentFD2901-AI                        7.484034
# HBF SpeedFD2901-SI                        140.783624
# CLOTH TRACK BELLOW 1 PRESSUREPI2902         0.194176
# CLOTH TRACK BELLOW 2 PRESSUREPI2903         0.358406
# CLOTH WASH PMP DISCH FLOWFI2909             4.649628
# Cakewash flowFIC2908                       27.199673
# Strong wash flowFIC2906                    25.139932
# Return acid flowFIC2905                    57.676222
# Product acid flowFIC2904                   28.957857
# HBF Vacuum pump ampsGB2901-AI               2.315226
# No 1 filtrate %P2O5                         0.705203
# No 1 filtrate Sp Gr                         0.013567
# No 1 filtrate FREEACID                      0.185453
# Gypsum TP2O5 loss                           0.220830
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# Weigh feeder rate AJD2706A-WIC.PV            23.988151
# Weigh feeder rate BJD2706B-WIC.PV           514.698951
# Ball mill ampsPA2729A-AI                    195.935021
# BALL MILL VENT SYS TEMPTI2705.PV              5.479177
# BALL MILL VENT FAN CURRENTGB2705-AI.PV      189.594851
# BAG FLTR SUC PRESSUREPI2705A.PV            1550.034416
# FAN SUC PRESSUREPI2705C.PV                11223.205121
# SCREW CONV - CURRENTJD2709-AI.PV              2.967079
# BUCKET ELEVATOR CURRENTJD2710-AI.PV           9.295943
# WEIGH FDR A FEED RATEJD2715A-WIC.PV         128.177430
# WEIGH FDR B FEED RATEJD2715B-WIC.PV         185.612921
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV         17.210661
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV         27.152894
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV     6429.370610
# ATTACK AGTR A CURRENTGD2801A-AI.PV           13.725873
# ATTACK AGTR B CURRENTGD2801B-AI.PV           15.399548
# ATTACK AGTR C CURRENTGD2801C-AI.PV           15.270860
# ATTACK AGTR D CURRENTGD2801D-AI.PV           19.727581
# ATTACK RCT B TEMPTI2801B.PV                   5.139459
# ATTACK RCT D TEMPTI2801D.PV                   4.613926
# Filter SPGPA2_FILSPG                          0.000090
# Slurry SPGPA2_SLURRYSPG                       0.000230
# Free AcidPA2_FREEACID                         0.040350
# Reactor SolidsREACT-SOLIDS.PV                 3.202900
# NEW DIGESTION TANK LEVELLI2802.PV            30.064143
# LOW LVL FLASH COOLER VACUUMPIC2801.PV       388.455475
# TD LLFC I/L & O/L TEMPTDY2806.PV              1.096242
# Slurry FlowFIC2902                         4402.655251
# LLFC CIRC PMP CURRENTGA2801-AI.PV             4.179023
# LLFC CIRC PMP SPEEDGA2801-SI.PV             241.582243
# Scrubber FanGB2801-AI                       113.702852
# HBF Vacuum PIC2917                         4143.500539
# HBF CurrentFD2901-AI                         56.010769
# HBF SpeedFD2901-SI                        19820.028867
# CLOTH TRACK BELLOW 1 PRESSUREPI2902           0.037704
# CLOTH TRACK BELLOW 2 PRESSUREPI2903           0.128455
# CLOTH WASH PMP DISCH FLOWFI2909              21.619038
# Cakewash flowFIC2908                        739.822204
# Strong wash flowFIC2906                     632.016162
# Return acid flowFIC2905                    3326.546560
# Product acid flowFIC2904                    838.557456
# HBF Vacuum pump ampsGB2901-AI                 5.360273
# No 1 filtrate %P2O5                           0.497312
# No 1 filtrate Sp Gr                           0.000184
# No 1 filtrate FREEACID                        0.034393
# Gypsum TP2O5 loss                             0.048766
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# Weigh feeder rate AJD2706A-WIC.PV            23.988151
# Weigh feeder rate BJD2706B-WIC.PV           514.698951
# Ball mill ampsPA2729A-AI                    195.935021
# BALL MILL VENT SYS TEMPTI2705.PV              5.479177
# BALL MILL VENT FAN CURRENTGB2705-AI.PV      189.594851
# BAG FLTR SUC PRESSUREPI2705A.PV            1550.034416
# FAN SUC PRESSUREPI2705C.PV                11223.205121
# SCREW CONV - CURRENTJD2709-AI.PV              2.967079
# BUCKET ELEVATOR CURRENTJD2710-AI.PV           9.295943
# WEIGH FDR A FEED RATEJD2715A-WIC.PV         128.177430
# WEIGH FDR B FEED RATEJD2715B-WIC.PV         185.612921
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV         17.210661
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV         27.152894
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV     6429.370610
# ATTACK AGTR A CURRENTGD2801A-AI.PV           13.725873
# ATTACK AGTR B CURRENTGD2801B-AI.PV           15.399548
# ATTACK AGTR C CURRENTGD2801C-AI.PV           15.270860
# ATTACK AGTR D CURRENTGD2801D-AI.PV           19.727581
# ATTACK RCT B TEMPTI2801B.PV                   5.139459
# ATTACK RCT D TEMPTI2801D.PV                   4.613926
# Filter SPGPA2_FILSPG                          0.000090
# Slurry SPGPA2_SLURRYSPG                       0.000230
# Free AcidPA2_FREEACID                         0.040350
# Reactor SolidsREACT-SOLIDS.PV                 3.202900
# NEW DIGESTION TANK LEVELLI2802.PV            30.064143
# LOW LVL FLASH COOLER VACUUMPIC2801.PV       388.455475
# TD LLFC I/L & O/L TEMPTDY2806.PV              1.096242
# Slurry FlowFIC2902                         4402.655251
# LLFC CIRC PMP CURRENTGA2801-AI.PV             4.179023
# LLFC CIRC PMP SPEEDGA2801-SI.PV             241.582243
# Scrubber FanGB2801-AI                       113.702852
# HBF Vacuum PIC2917                         4143.500539
# HBF CurrentFD2901-AI                         56.010769
# HBF SpeedFD2901-SI                        19820.028867
# CLOTH TRACK BELLOW 1 PRESSUREPI2902           0.037704
# CLOTH TRACK BELLOW 2 PRESSUREPI2903           0.128455
# CLOTH WASH PMP DISCH FLOWFI2909              21.619038
# Cakewash flowFIC2908                        739.822204
# Strong wash flowFIC2906                     632.016162
# Return acid flowFIC2905                    3326.546560
# Product acid flowFIC2904                    838.557456
# HBF Vacuum pump ampsGB2901-AI                 5.360273
# No 1 filtrate %P2O5                           0.497312
# No 1 filtrate Sp Gr                           0.000184
# No 1 filtrate FREEACID                        0.034393
# Gypsum TP2O5 loss                             0.048766
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Weigh feeder rate AJD2706A-WIC.PV          22.031294
# Weigh feeder rate BJD2706B-WIC.PV          98.132406
# Ball mill ampsPA2729A-AI                   94.943709
# BALL MILL VENT SYS TEMPTI2705.PV           52.741472
# BALL MILL VENT FAN CURRENTGB2705-AI.PV     84.242000
# BAG FLTR SUC PRESSUREPI2705A.PV            -0.375329
# FAN SUC PRESSUREPI2705C.PV                 -0.018210
# SCREW CONV - CURRENTJD2709-AI.PV           29.032222
# BUCKET ELEVATOR CURRENTJD2710-AI.PV        32.109132
# WEIGH FDR A FEED RATEJD2715A-WIC.PV        82.677653
# WEIGH FDR B FEED RATEJD2715B-WIC.PV        98.256881
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV       30.486267
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV       38.438783
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV    186.726174
# ATTACK AGTR A CURRENTGD2801A-AI.PV        212.281714
# ATTACK AGTR B CURRENTGD2801B-AI.PV        209.736649
# ATTACK AGTR C CURRENTGD2801C-AI.PV        219.145682
# ATTACK AGTR D CURRENTGD2801D-AI.PV        231.782650
# ATTACK RCT B TEMPTI2801B.PV                86.312780
# ATTACK RCT D TEMPTI2801D.PV                85.597361
# Filter SPGPA2_FILSPG                        1.340000
# Slurry SPGPA2_SLURRYSPG                     1.695156
# Free AcidPA2_FREEACID                       3.120000
# Reactor SolidsREACT-SOLIDS.PV              49.248596
# NEW DIGESTION TANK LEVELLI2802.PV         103.217271
# LOW LVL FLASH COOLER VACUUMPIC2801.PV     551.332411
# TD LLFC I/L & O/L TEMPTDY2806.PV            7.362182
# Slurry FlowFIC2902                        449.284221
# LLFC CIRC PMP CURRENTGA2801-AI.PV         230.005410
# LLFC CIRC PMP SPEEDGA2801-SI.PV           749.004757
# Scrubber FanGB2801-AI                     154.897380
# HBF Vacuum PIC2917                         -3.950243
# HBF CurrentFD2901-AI                       63.727820
# HBF SpeedFD2901-SI                        960.098318
# CLOTH TRACK BELLOW 1 PRESSUREPI2902         1.785766
# CLOTH TRACK BELLOW 2 PRESSUREPI2903         1.730945
# CLOTH WASH PMP DISCH FLOWFI2909            43.946866
# Cakewash flowFIC2908                      202.822852
# Strong wash flowFIC2906                   225.547049
# Return acid flowFIC2905                   389.155414
# Product acid flowFIC2904                  136.549529
# HBF Vacuum pump ampsGB2901-AI              22.091710
# No 1 filtrate %P2O5                        26.680000
# No 1 filtrate Sp Gr                         1.328000
# No 1 filtrate FREEACID                      2.850000
# Gypsum TP2O5 loss                           2.270000
# dtype: float64

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outlier_count = (
        (df[col] < lower) |
        (df[col] > upper)
    ).sum()

    print(col, ":", outlier_count)
# Out:
# Weigh feeder rate AJD2706A-WIC.PV : 1234
# Weigh feeder rate BJD2706B-WIC.PV : 1189
# Ball mill ampsPA2729A-AI : 1560
# BALL MILL VENT SYS TEMPTI2705.PV : 1361
# BALL MILL VENT FAN CURRENTGB2705-AI.PV : 949
# BAG FLTR SUC PRESSUREPI2705A.PV : 1288
# FAN SUC PRESSUREPI2705C.PV : 1597
# SCREW CONV - CURRENTJD2709-AI.PV : 48
# BUCKET ELEVATOR CURRENTJD2710-AI.PV : 1463
# WEIGH FDR A FEED RATEJD2715A-WIC.PV : 1393
# WEIGH FDR B FEED RATEJD2715B-WIC.PV : 2080
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV : 1968
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV : 686
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV : 0
# ATTACK AGTR A CURRENTGD2801A-AI.PV : 55
# ATTACK AGTR B CURRENTGD2801B-AI.PV : 133
# ATTACK AGTR C CURRENTGD2801C-AI.PV : 98
# ATTACK AGTR D CURRENTGD2801D-AI.PV : 130
# ATTACK RCT B TEMPTI2801B.PV : 445
# ATTACK RCT D TEMPTI2801D.PV : 440
# Filter SPGPA2_FILSPG : 432
# Slurry SPGPA2_SLURRYSPG : 67
# Free AcidPA2_FREEACID : 381
# Reactor SolidsREACT-SOLIDS.PV : 452
# NEW DIGESTION TANK LEVELLI2802.PV : 1651
# LOW LVL FLASH COOLER VACUUMPIC2801.PV : 347
# TD LLFC I/L & O/L TEMPTDY2806.PV : 481
# Slurry FlowFIC2902 : 367
# LLFC CIRC PMP CURRENTGA2801-AI.PV : 207
# LLFC CIRC PMP SPEEDGA2801-SI.PV : 200
# Scrubber FanGB2801-AI : 2197
# HBF Vacuum PIC2917 : 423
# HBF CurrentFD2901-AI : 550
# HBF SpeedFD2901-SI : 227
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 : 216
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 : 57
# CLOTH WASH PMP DISCH FLOWFI2909 : 166
# Cakewash flowFIC2908 : 931
# Strong wash flowFIC2906 : 1736
# Return acid flowFIC2905 : 1412
# Product acid flowFIC2904 : 548
# HBF Vacuum pump ampsGB2901-AI : 391
# No 1 filtrate %P2O5 : 886
# No 1 filtrate Sp Gr : 406
# No 1 filtrate FREEACID : 364
# Gypsum TP2O5 loss : 480

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.boxplot(
    df["ATTACK AGTR A CURRENTGD2801A-AI.PV"]
)

plt.title("AGTR A Boxplot")
plt.show()

# %%
corr_matrix = df.corr(
    numeric_only=True
)

# %%
corr_matrix
# Out:
#                                         Weigh feeder rate AJD2706A-WIC.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                                1.000000
# Weigh feeder rate BJD2706B-WIC.PV                                0.970800
# Ball mill ampsPA2729A-AI                                         0.540014
# BALL MILL VENT SYS TEMPTI2705.PV                                 0.106375
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                           0.728915
# BAG FLTR SUC PRESSUREPI2705A.PV                                 -0.295245
# FAN SUC PRESSUREPI2705C.PV                                      -0.790003
# SCREW CONV - CURRENTJD2709-AI.PV                                 0.184187
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                             -0.069017
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                              0.214265
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                              0.134329
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                             0.265288
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                             0.130671
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                           0.253737
# ATTACK AGTR A CURRENTGD2801A-AI.PV                              -0.039001
# ATTACK AGTR B CURRENTGD2801B-AI.PV                               0.102502
# ATTACK AGTR C CURRENTGD2801C-AI.PV                              -0.048270
# ATTACK AGTR D CURRENTGD2801D-AI.PV                              -0.026508
# ATTACK RCT B TEMPTI2801B.PV                                      0.431813
# ATTACK RCT D TEMPTI2801D.PV                                      0.439676
# Filter SPGPA2_FILSPG                                             0.132188
# Slurry SPGPA2_SLURRYSPG                                          0.042431
# Free AcidPA2_FREEACID                                            0.182989
# Reactor SolidsREACT-SOLIDS.PV                                   -0.041662
# NEW DIGESTION TANK LEVELLI2802.PV                               -0.168094
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                           -0.418467
# TD LLFC I/L & O/L TEMPTDY2806.PV                                 0.080133
# Slurry FlowFIC2902                                               0.129473
# LLFC CIRC PMP CURRENTGA2801-AI.PV                                0.133226
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                  0.267456
# Scrubber FanGB2801-AI                                           -0.147733
# HBF Vacuum PIC2917                                              -0.099793
# HBF CurrentFD2901-AI                                             0.106288
# HBF SpeedFD2901-SI                                               0.155873
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                              0.084575
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                             -0.073004
# CLOTH WASH PMP DISCH FLOWFI2909                                  0.025183
# Cakewash flowFIC2908                                             0.138069
# Strong wash flowFIC2906                                          0.132989
# Return acid flowFIC2905                                          0.100662
# Product acid flowFIC2904                                         0.156207
# HBF Vacuum pump ampsGB2901-AI                                    0.145271
# No 1 filtrate %P2O5                                              0.185335
# No 1 filtrate Sp Gr                                              0.153333
# No 1 filtrate FREEACID                                          -0.132818
# Gypsum TP2O5 loss                                                0.002204
#
#                                         Weigh feeder rate BJD2706B-WIC.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                                0.970800
# Weigh feeder rate BJD2706B-WIC.PV                                1.000000
# Ball mill ampsPA2729A-AI                                         0.513831
# BALL MILL VENT SYS TEMPTI2705.PV                                 0.076584
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                           0.715194
# BAG FLTR SUC PRESSUREPI2705A.PV                                 -0.257787
# FAN SUC PRESSUREPI2705C.PV                                      -0.787251
# SCREW CONV - CURRENTJD2709-AI.PV                                 0.186947
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                             -0.069905
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                              0.205797
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                              0.130341
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                             0.260994
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                             0.122162
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                           0.235823
# ATTACK AGTR A CURRENTGD2801A-AI.PV                              -0.033805
# ATTACK AGTR B CURRENTGD2801B-AI.PV                               0.096232
# ATTACK AGTR C CURRENTGD2801C-AI.PV                              -0.043399
# ATTACK AGTR D CURRENTGD2801D-AI.PV                              -0.023627
# ATTACK RCT B TEMPTI2801B.PV                                      0.414359
# ATTACK RCT D TEMPTI2801D.PV                                      0.419051
# Filter SPGPA2_FILSPG                                             0.136467
# Slurry SPGPA2_SLURRYSPG                                          0.043198
# Free AcidPA2_FREEACID                                            0.182938
# Reactor SolidsREACT-SOLIDS.PV                                   -0.043704
# NEW DIGESTION TANK LEVELLI2802.PV                               -0.160788
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                           -0.402648
# TD LLFC I/L & O/L TEMPTDY2806.PV                                 0.076632
# Slurry FlowFIC2902                                               0.124034
# LLFC CIRC PMP CURRENTGA2801-AI.PV                                0.130026
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                  0.257895
# Scrubber FanGB2801-AI                                           -0.144483
# HBF Vacuum PIC2917                                              -0.093592
# HBF CurrentFD2901-AI                                             0.100799
# HBF SpeedFD2901-SI                                               0.151766
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                              0.074226
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                             -0.059709
# CLOTH WASH PMP DISCH FLOWFI2909                                  0.028542
# Cakewash flowFIC2908                                             0.132309
# Strong wash flowFIC2906                                          0.125956
# Return acid flowFIC2905                                          0.096272
# Product acid flowFIC2904                                         0.148560
# HBF Vacuum pump ampsGB2901-AI                                    0.136833
# No 1 filtrate %P2O5                                              0.177790
# No 1 filtrate Sp Gr                                              0.146527
# No 1 filtrate FREEACID                                          -0.115612
# Gypsum TP2O5 loss                                                0.003845
#
#                                         Ball mill ampsPA2729A-AI  \
# Weigh feeder rate AJD2706A-WIC.PV                       0.540014
# Weigh feeder rate BJD2706B-WIC.PV                       0.513831
# Ball mill ampsPA2729A-AI                                1.000000
# BALL MILL VENT SYS TEMPTI2705.PV                        0.648311
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                  0.643602
# BAG FLTR SUC PRESSUREPI2705A.PV                        -0.344675
# FAN SUC PRESSUREPI2705C.PV                             -0.650438
# SCREW CONV - CURRENTJD2709-AI.PV                        0.302849
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                     0.158126
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                     0.062724
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                     0.012197
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                    0.047940
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                   -0.017547
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                  0.129441
# ATTACK AGTR A CURRENTGD2801A-AI.PV                     -0.009912
# ATTACK AGTR B CURRENTGD2801B-AI.PV                      0.042975
# ATTACK AGTR C CURRENTGD2801C-AI.PV                     -0.017045
# ATTACK AGTR D CURRENTGD2801D-AI.PV                     -0.005230
# ATTACK RCT B TEMPTI2801B.PV                             0.284768
# ATTACK RCT D TEMPTI2801D.PV                             0.318817
# Filter SPGPA2_FILSPG                                    0.085843
# Slurry SPGPA2_SLURRYSPG                                -0.015002
# Free AcidPA2_FREEACID                                   0.223262
# Reactor SolidsREACT-SOLIDS.PV                          -0.076091
# NEW DIGESTION TANK LEVELLI2802.PV                      -0.028918
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                  -0.203958
# TD LLFC I/L & O/L TEMPTDY2806.PV                       -0.103214
# Slurry FlowFIC2902                                      0.083963
# LLFC CIRC PMP CURRENTGA2801-AI.PV                       0.127418
# LLFC CIRC PMP SPEEDGA2801-SI.PV                         0.336867
# Scrubber FanGB2801-AI                                  -0.116713
# HBF Vacuum PIC2917                                     -0.052094
# HBF CurrentFD2901-AI                                    0.034608
# HBF SpeedFD2901-SI                                      0.073059
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                     0.153569
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                    -0.118016
# CLOTH WASH PMP DISCH FLOWFI2909                        -0.038518
# Cakewash flowFIC2908                                    0.062785
# Strong wash flowFIC2906                                 0.059574
# Return acid flowFIC2905                                 0.064739
# Product acid flowFIC2904                                0.054347
# HBF Vacuum pump ampsGB2901-AI                           0.095940
# No 1 filtrate %P2O5                                     0.194315
# No 1 filtrate Sp Gr                                     0.151320
# No 1 filtrate FREEACID                                 -0.139574
# Gypsum TP2O5 loss                                      -0.010459
#
#                                         BALL MILL VENT SYS TEMPTI2705.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                               0.106375
# Weigh feeder rate BJD2706B-WIC.PV                               0.076584
# Ball mill ampsPA2729A-AI                                        0.648311
# BALL MILL VENT SYS TEMPTI2705.PV                                1.000000
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                          0.384469
# BAG FLTR SUC PRESSUREPI2705A.PV                                -0.497377
# FAN SUC PRESSUREPI2705C.PV                                     -0.263291
# SCREW CONV - CURRENTJD2709-AI.PV                                0.195774
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                             0.207085
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                            -0.081604
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                            -0.094921
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                           -0.147777
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                           -0.108486
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                         -0.065479
# ATTACK AGTR A CURRENTGD2801A-AI.PV                              0.026777
# ATTACK AGTR B CURRENTGD2801B-AI.PV                             -0.044288
# ATTACK AGTR C CURRENTGD2801C-AI.PV                              0.005684
# ATTACK AGTR D CURRENTGD2801D-AI.PV                              0.009513
# ATTACK RCT B TEMPTI2801B.PV                                    -0.095432
# ATTACK RCT D TEMPTI2801D.PV                                    -0.054962
# Filter SPGPA2_FILSPG                                           -0.071279
# Slurry SPGPA2_SLURRYSPG                                        -0.097811
# Free AcidPA2_FREEACID                                           0.049086
# Reactor SolidsREACT-SOLIDS.PV                                  -0.063692
# NEW DIGESTION TANK LEVELLI2802.PV                               0.154283
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                           0.162342
# TD LLFC I/L & O/L TEMPTDY2806.PV                               -0.183771
# Slurry FlowFIC2902                                              0.079036
# LLFC CIRC PMP CURRENTGA2801-AI.PV                               0.018782
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                 0.239768
# Scrubber FanGB2801-AI                                           0.007452
# HBF Vacuum PIC2917                                             -0.036931
# HBF CurrentFD2901-AI                                            0.018856
# HBF SpeedFD2901-SI                                              0.022067
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                             0.128078
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                            -0.090611
# CLOTH WASH PMP DISCH FLOWFI2909                                -0.018986
# Cakewash flowFIC2908                                            0.002679
# Strong wash flowFIC2906                                         0.011027
# Return acid flowFIC2905                                         0.053883
# Product acid flowFIC2904                                       -0.017533
# HBF Vacuum pump ampsGB2901-AI                                   0.038135
# No 1 filtrate %P2O5                                             0.092213
# No 1 filtrate Sp Gr                                             0.050860
# No 1 filtrate FREEACID                                         -0.056210
# Gypsum TP2O5 loss                                              -0.024976
#
#                                         BALL MILL VENT FAN CURRENTGB2705-AI.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                                     0.728915
# Weigh feeder rate BJD2706B-WIC.PV                                     0.715194
# Ball mill ampsPA2729A-AI                                              0.643602
# BALL MILL VENT SYS TEMPTI2705.PV                                      0.384469
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                                1.000000
# BAG FLTR SUC PRESSUREPI2705A.PV                                      -0.542075
# FAN SUC PRESSUREPI2705C.PV                                           -0.950477
# SCREW CONV - CURRENTJD2709-AI.PV                                      0.213710
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                                   0.097439
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                                   0.041534
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                                   0.042744
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                                  0.046215
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                                  0.018399
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                                0.070425
# ATTACK AGTR A CURRENTGD2801A-AI.PV                                    0.073119
# ATTACK AGTR B CURRENTGD2801B-AI.PV                                    0.069249
# ATTACK AGTR C CURRENTGD2801C-AI.PV                                    0.052066
# ATTACK AGTR D CURRENTGD2801D-AI.PV                                    0.037310
# ATTACK RCT B TEMPTI2801B.PV                                           0.236352
# ATTACK RCT D TEMPTI2801D.PV                                           0.255893
# Filter SPGPA2_FILSPG                                                  0.050641
# Slurry SPGPA2_SLURRYSPG                                              -0.024213
# Free AcidPA2_FREEACID                                                 0.173200
# Reactor SolidsREACT-SOLIDS.PV                                        -0.062836
# NEW DIGESTION TANK LEVELLI2802.PV                                    -0.076270
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                                -0.172856
# TD LLFC I/L & O/L TEMPTDY2806.PV                                     -0.010515
# Slurry FlowFIC2902                                                    0.078165
# LLFC CIRC PMP CURRENTGA2801-AI.PV                                     0.084439
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                       0.257611
# Scrubber FanGB2801-AI                                                -0.038259
# HBF Vacuum PIC2917                                                   -0.046653
# HBF CurrentFD2901-AI                                                  0.049829
# HBF SpeedFD2901-SI                                                    0.081873
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                                   0.125447
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                                  -0.071967
# CLOTH WASH PMP DISCH FLOWFI2909                                       0.005124
# Cakewash flowFIC2908                                                  0.044583
# Strong wash flowFIC2906                                               0.030765
# Return acid flowFIC2905                                               0.044852
# Product acid flowFIC2904                                              0.026483
# HBF Vacuum pump ampsGB2901-AI                                         0.066636
# No 1 filtrate %P2O5                                                   0.094626
# No 1 filtrate Sp Gr                                                   0.076893
# No 1 filtrate FREEACID                                               -0.062046
# Gypsum TP2O5 loss                                                     0.019871
#
#                                         BAG FLTR SUC PRESSUREPI2705A.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                             -0.295245
# Weigh feeder rate BJD2706B-WIC.PV                             -0.257787
# Ball mill ampsPA2729A-AI                                      -0.344675
# BALL MILL VENT SYS TEMPTI2705.PV                              -0.497377
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                        -0.542075
# BAG FLTR SUC PRESSUREPI2705A.PV                                1.000000
# FAN SUC PRESSUREPI2705C.PV                                     0.299158
# SCREW CONV - CURRENTJD2709-AI.PV                              -0.041080
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                            0.017114
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                           -0.008189
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                            0.048178
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                           0.001307
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                           0.054827
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                        -0.152859
# ATTACK AGTR A CURRENTGD2801A-AI.PV                             0.011232
# ATTACK AGTR B CURRENTGD2801B-AI.PV                            -0.014092
# ATTACK AGTR C CURRENTGD2801C-AI.PV                             0.014751
# ATTACK AGTR D CURRENTGD2801D-AI.PV                            -0.021493
# ATTACK RCT B TEMPTI2801B.PV                                   -0.091978
# ATTACK RCT D TEMPTI2801D.PV                                   -0.109246
# Filter SPGPA2_FILSPG                                          -0.080295
# Slurry SPGPA2_SLURRYSPG                                       -0.000370
# Free AcidPA2_FREEACID                                         -0.100813
# Reactor SolidsREACT-SOLIDS.PV                                  0.053702
# NEW DIGESTION TANK LEVELLI2802.PV                              0.105560
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                          0.033639
# TD LLFC I/L & O/L TEMPTDY2806.PV                               0.072850
# Slurry FlowFIC2902                                             0.006580
# LLFC CIRC PMP CURRENTGA2801-AI.PV                             -0.015481
# LLFC CIRC PMP SPEEDGA2801-SI.PV                               -0.095506
# Scrubber FanGB2801-AI                                          0.092415
# HBF Vacuum PIC2917                                            -0.022838
# HBF CurrentFD2901-AI                                           0.006491
# HBF SpeedFD2901-SI                                            -0.012901
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                           -0.031942
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                            0.013277
# CLOTH WASH PMP DISCH FLOWFI2909                                0.005626
# Cakewash flowFIC2908                                          -0.032688
# Strong wash flowFIC2906                                       -0.004399
# Return acid flowFIC2905                                        0.003638
# Product acid flowFIC2904                                      -0.051440
# HBF Vacuum pump ampsGB2901-AI                                 -0.003501
# No 1 filtrate %P2O5                                           -0.072981
# No 1 filtrate Sp Gr                                           -0.073577
# No 1 filtrate FREEACID                                         0.088663
# Gypsum TP2O5 loss                                             -0.029518
#
#                                         FAN SUC PRESSUREPI2705C.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                        -0.790003
# Weigh feeder rate BJD2706B-WIC.PV                        -0.787251
# Ball mill ampsPA2729A-AI                                 -0.650438
# BALL MILL VENT SYS TEMPTI2705.PV                         -0.263291
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                   -0.950477
# BAG FLTR SUC PRESSUREPI2705A.PV                           0.299158
# FAN SUC PRESSUREPI2705C.PV                                1.000000
# SCREW CONV - CURRENTJD2709-AI.PV                         -0.208298
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                      -0.094980
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                      -0.084629
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                      -0.066823
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                     -0.101016
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                     -0.047843
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                   -0.096964
# ATTACK AGTR A CURRENTGD2801A-AI.PV                       -0.015886
# ATTACK AGTR B CURRENTGD2801B-AI.PV                       -0.074677
# ATTACK AGTR C CURRENTGD2801C-AI.PV                        0.000577
# ATTACK AGTR D CURRENTGD2801D-AI.PV                        0.001598
# ATTACK RCT B TEMPTI2801B.PV                              -0.292370
# ATTACK RCT D TEMPTI2801D.PV                              -0.309107
# Filter SPGPA2_FILSPG                                     -0.068744
# Slurry SPGPA2_SLURRYSPG                                   0.017479
# Free AcidPA2_FREEACID                                    -0.173617
# Reactor SolidsREACT-SOLIDS.PV                             0.067402
# NEW DIGESTION TANK LEVELLI2802.PV                         0.075882
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                     0.246339
# TD LLFC I/L & O/L TEMPTDY2806.PV                         -0.003251
# Slurry FlowFIC2902                                       -0.107166
# LLFC CIRC PMP CURRENTGA2801-AI.PV                        -0.085134
# LLFC CIRC PMP SPEEDGA2801-SI.PV                          -0.287761
# Scrubber FanGB2801-AI                                     0.058687
# HBF Vacuum PIC2917                                        0.067795
# HBF CurrentFD2901-AI                                     -0.067225
# HBF SpeedFD2901-SI                                       -0.106606
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                      -0.115532
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                       0.088218
# CLOTH WASH PMP DISCH FLOWFI2909                          -0.005272
# Cakewash flowFIC2908                                     -0.058690
# Strong wash flowFIC2906                                  -0.059892
# Return acid flowFIC2905                                  -0.065967
# Product acid flowFIC2904                                 -0.056773
# HBF Vacuum pump ampsGB2901-AI                            -0.097121
# No 1 filtrate %P2O5                                      -0.133019
# No 1 filtrate Sp Gr                                      -0.109884
# No 1 filtrate FREEACID                                    0.076765
# Gypsum TP2O5 loss                                        -0.014576
#
#                                         SCREW CONV - CURRENTJD2709-AI.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                               0.184187
# Weigh feeder rate BJD2706B-WIC.PV                               0.186947
# Ball mill ampsPA2729A-AI                                        0.302849
# BALL MILL VENT SYS TEMPTI2705.PV                                0.195774
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                          0.213710
# BAG FLTR SUC PRESSUREPI2705A.PV                                -0.041080
# FAN SUC PRESSUREPI2705C.PV                                     -0.208298
# SCREW CONV - CURRENTJD2709-AI.PV                                1.000000
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                             0.259210
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                             0.150446
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                             0.109210
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                            0.128466
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                            0.184176
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                         -0.038898
# ATTACK AGTR A CURRENTGD2801A-AI.PV                              0.245223
# ATTACK AGTR B CURRENTGD2801B-AI.PV                              0.171815
# ATTACK AGTR C CURRENTGD2801C-AI.PV                              0.222639
# ATTACK AGTR D CURRENTGD2801D-AI.PV                              0.172175
# ATTACK RCT B TEMPTI2801B.PV                                     0.258108
# ATTACK RCT D TEMPTI2801D.PV                                     0.258708
# Filter SPGPA2_FILSPG                                           -0.055279
# Slurry SPGPA2_SLURRYSPG                                        -0.051261
# Free AcidPA2_FREEACID                                          -0.023915
# Reactor SolidsREACT-SOLIDS.PV                                  -0.022280
# NEW DIGESTION TANK LEVELLI2802.PV                               0.094642
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                          -0.177517
# TD LLFC I/L & O/L TEMPTDY2806.PV                                0.200319
# Slurry FlowFIC2902                                              0.226060
# LLFC CIRC PMP CURRENTGA2801-AI.PV                               0.333399
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                 0.636830
# Scrubber FanGB2801-AI                                           0.105725
# HBF Vacuum PIC2917                                             -0.241447
# HBF CurrentFD2901-AI                                            0.278445
# HBF SpeedFD2901-SI                                              0.231868
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                             0.386716
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                            -0.152879
# CLOTH WASH PMP DISCH FLOWFI2909                                 0.227980
# Cakewash flowFIC2908                                            0.226438
# Strong wash flowFIC2906                                         0.224897
# Return acid flowFIC2905                                         0.220501
# Product acid flowFIC2904                                        0.109766
# HBF Vacuum pump ampsGB2901-AI                                   0.325894
# No 1 filtrate %P2O5                                             0.053327
# No 1 filtrate Sp Gr                                             0.007744
# No 1 filtrate FREEACID                                          0.017064
# Gypsum TP2O5 loss                                               0.061637
#
#                                         BUCKET ELEVATOR CURRENTJD2710-AI.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                                 -0.069017
# Weigh feeder rate BJD2706B-WIC.PV                                 -0.069905
# Ball mill ampsPA2729A-AI                                           0.158126
# BALL MILL VENT SYS TEMPTI2705.PV                                   0.207085
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                             0.097439
# BAG FLTR SUC PRESSUREPI2705A.PV                                    0.017114
# FAN SUC PRESSUREPI2705C.PV                                        -0.094980
# SCREW CONV - CURRENTJD2709-AI.PV                                   0.259210
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                                1.000000
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                               -0.152065
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                               -0.119344
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                              -0.249624
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                              -0.142430
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                            -0.192599
# ATTACK AGTR A CURRENTGD2801A-AI.PV                                 0.049456
# ATTACK AGTR B CURRENTGD2801B-AI.PV                                 0.025023
# ATTACK AGTR C CURRENTGD2801C-AI.PV                                 0.046130
# ATTACK AGTR D CURRENTGD2801D-AI.PV                                 0.031619
# ATTACK RCT B TEMPTI2801B.PV                                       -0.025294
# ATTACK RCT D TEMPTI2801D.PV                                       -0.013864
# Filter SPGPA2_FILSPG                                              -0.032063
# Slurry SPGPA2_SLURRYSPG                                           -0.024048
# Free AcidPA2_FREEACID                                              0.130392
# Reactor SolidsREACT-SOLIDS.PV                                     -0.004358
# NEW DIGESTION TANK LEVELLI2802.PV                                  0.218650
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                              0.123938
# TD LLFC I/L & O/L TEMPTDY2806.PV                                  -0.153161
# Slurry FlowFIC2902                                                -0.015696
# LLFC CIRC PMP CURRENTGA2801-AI.PV                                  0.023409
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                    0.174621
# Scrubber FanGB2801-AI                                              0.027438
# HBF Vacuum PIC2917                                                 0.013586
# HBF CurrentFD2901-AI                                              -0.054223
# HBF SpeedFD2901-SI                                                 0.020530
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                                0.081400
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                               -0.049690
# CLOTH WASH PMP DISCH FLOWFI2909                                   -0.056306
# Cakewash flowFIC2908                                              -0.048903
# Strong wash flowFIC2906                                           -0.033998
# Return acid flowFIC2905                                           -0.034275
# Product acid flowFIC2904                                          -0.057462
# HBF Vacuum pump ampsGB2901-AI                                     -0.042008
# No 1 filtrate %P2O5                                                0.054021
# No 1 filtrate Sp Gr                                                0.125736
# No 1 filtrate FREEACID                                             0.046663
# Gypsum TP2O5 loss                                                  0.017481
#
#                                         WEIGH FDR A FEED RATEJD2715A-WIC.PV  \
# Weigh feeder rate AJD2706A-WIC.PV                                  0.214265
# Weigh feeder rate BJD2706B-WIC.PV                                  0.205797
# Ball mill ampsPA2729A-AI                                           0.062724
# BALL MILL VENT SYS TEMPTI2705.PV                                  -0.081604
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                             0.041534
# BAG FLTR SUC PRESSUREPI2705A.PV                                   -0.008189
# FAN SUC PRESSUREPI2705C.PV                                        -0.084629
# SCREW CONV - CURRENTJD2709-AI.PV                                   0.150446
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                               -0.152065
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                                1.000000
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                                0.163541
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                               0.654925
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                               0.510509
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                             0.239568
# ATTACK AGTR A CURRENTGD2801A-AI.PV                                -0.032427
# ATTACK AGTR B CURRENTGD2801B-AI.PV                                 0.201381
# ATTACK AGTR C CURRENTGD2801C-AI.PV                                 0.028087
# ATTACK AGTR D CURRENTGD2801D-AI.PV                                 0.087115
# ATTACK RCT B TEMPTI2801B.PV                                        0.333517
# ATTACK RCT D TEMPTI2801D.PV                                        0.315257
# Filter SPGPA2_FILSPG                                               0.017611
# Slurry SPGPA2_SLURRYSPG                                           -0.049538
# Free AcidPA2_FREEACID                                             -0.049245
# Reactor SolidsREACT-SOLIDS.PV                                     -0.069449
# NEW DIGESTION TANK LEVELLI2802.PV                                 -0.100795
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                             -0.430178
# TD LLFC I/L & O/L TEMPTDY2806.PV                                   0.260506
# Slurry FlowFIC2902                                                 0.397432
# LLFC CIRC PMP CURRENTGA2801-AI.PV                                  0.127006
# LLFC CIRC PMP SPEEDGA2801-SI.PV                                    0.321729
# Scrubber FanGB2801-AI                                             -0.078980
# HBF Vacuum PIC2917                                                -0.289367
# HBF CurrentFD2901-AI                                               0.428759
# HBF SpeedFD2901-SI                                                 0.393960
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                                0.101423
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                               -0.041788
# CLOTH WASH PMP DISCH FLOWFI2909                                    0.343633
# Cakewash flowFIC2908                                               0.360965
# Strong wash flowFIC2906                                            0.394869
# Return acid flowFIC2905                                            0.335218
# Product acid flowFIC2904                                           0.329497
# HBF Vacuum pump ampsGB2901-AI                                      0.481503
# No 1 filtrate %P2O5                                                0.084911
# No 1 filtrate Sp Gr                                                0.117877
# No 1 filtrate FREEACID                                            -0.054082
# Gypsum TP2O5 loss                                                 -0.107495
#
#                                         ...  CLOTH WASH PMP DISCH FLOWFI2909  \
# Weigh feeder rate AJD2706A-WIC.PV       ...                         0.025183
# Weigh feeder rate BJD2706B-WIC.PV       ...                         0.028542
# Ball mill ampsPA2729A-AI                ...                        -0.038518
# BALL MILL VENT SYS TEMPTI2705.PV        ...                        -0.018986
# BALL MILL VENT FAN CURRENTGB2705-AI.PV  ...                         0.005124
# BAG FLTR SUC PRESSUREPI2705A.PV         ...                         0.005626
# FAN SUC PRESSUREPI2705C.PV              ...                        -0.005272
# SCREW CONV - CURRENTJD2709-AI.PV        ...                         0.227980
# BUCKET ELEVATOR CURRENTJD2710-AI.PV     ...                        -0.056306
# WEIGH FDR A FEED RATEJD2715A-WIC.PV     ...                         0.343633
# WEIGH FDR B FEED RATEJD2715B-WIC.PV     ...                         0.242330
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV    ...                         0.424129
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV    ...                         0.311611
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV  ...                         0.235361
# ATTACK AGTR A CURRENTGD2801A-AI.PV      ...                         0.150845
# ATTACK AGTR B CURRENTGD2801B-AI.PV      ...                        -0.043520
# ATTACK AGTR C CURRENTGD2801C-AI.PV      ...                        -0.032924
# ATTACK AGTR D CURRENTGD2801D-AI.PV      ...                        -0.014572
# ATTACK RCT B TEMPTI2801B.PV             ...                         0.082557
# ATTACK RCT D TEMPTI2801D.PV             ...                         0.076745
# Filter SPGPA2_FILSPG                    ...                        -0.068207
# Slurry SPGPA2_SLURRYSPG                 ...                        -0.099953
# Free AcidPA2_FREEACID                   ...                        -0.138043
# Reactor SolidsREACT-SOLIDS.PV           ...                        -0.067721
# NEW DIGESTION TANK LEVELLI2802.PV       ...                        -0.149802
# LOW LVL FLASH COOLER VACUUMPIC2801.PV   ...                        -0.183814
# TD LLFC I/L & O/L TEMPTDY2806.PV        ...                         0.280865
# Slurry FlowFIC2902                      ...                         0.537222
# LLFC CIRC PMP CURRENTGA2801-AI.PV       ...                         0.168430
# LLFC CIRC PMP SPEEDGA2801-SI.PV         ...                         0.239074
# Scrubber FanGB2801-AI                   ...                         0.416793
# HBF Vacuum PIC2917                      ...                        -0.552492
# HBF CurrentFD2901-AI                    ...                         0.713880
# HBF SpeedFD2901-SI                      ...                         0.676354
# CLOTH TRACK BELLOW 1 PRESSUREPI2902     ...                        -0.058459
# CLOTH TRACK BELLOW 2 PRESSUREPI2903     ...                         0.278753
# CLOTH WASH PMP DISCH FLOWFI2909         ...                         1.000000
# Cakewash flowFIC2908                    ...                         0.410237
# Strong wash flowFIC2906                 ...                         0.462032
# Return acid flowFIC2905                 ...                         0.505530
# Product acid flowFIC2904                ...                         0.347126
# HBF Vacuum pump ampsGB2901-AI           ...                         0.691544
# No 1 filtrate %P2O5                     ...                        -0.089123
# No 1 filtrate Sp Gr                     ...                        -0.134759
# No 1 filtrate FREEACID                  ...                        -0.071943
# Gypsum TP2O5 loss                       ...                         0.008398
#
#                                         Cakewash flowFIC2908  \
# Weigh feeder rate AJD2706A-WIC.PV                   0.138069
# Weigh feeder rate BJD2706B-WIC.PV                   0.132309
# Ball mill ampsPA2729A-AI                            0.062785
# BALL MILL VENT SYS TEMPTI2705.PV                    0.002679
# BALL MILL VENT FAN CURRENTGB2705-AI.PV              0.044583
# BAG FLTR SUC PRESSUREPI2705A.PV                    -0.032688
# FAN SUC PRESSUREPI2705C.PV                         -0.058690
# SCREW CONV - CURRENTJD2709-AI.PV                    0.226438
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                -0.048903
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                 0.360965
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                 0.268627
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                0.334010
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                0.413824
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV              0.076041
# ATTACK AGTR A CURRENTGD2801A-AI.PV                  0.173741
# ATTACK AGTR B CURRENTGD2801B-AI.PV                  0.221048
# ATTACK AGTR C CURRENTGD2801C-AI.PV                  0.141067
# ATTACK AGTR D CURRENTGD2801D-AI.PV                  0.127786
# ATTACK RCT B TEMPTI2801B.PV                         0.281653
# ATTACK RCT D TEMPTI2801D.PV                         0.280514
# Filter SPGPA2_FILSPG                                0.266305
# Slurry SPGPA2_SLURRYSPG                             0.270390
# Free AcidPA2_FREEACID                               0.007800
# Reactor SolidsREACT-SOLIDS.PV                       0.130905
# NEW DIGESTION TANK LEVELLI2802.PV                  -0.125270
# LOW LVL FLASH COOLER VACUUMPIC2801.PV              -0.288823
# TD LLFC I/L & O/L TEMPTDY2806.PV                    0.211887
# Slurry FlowFIC2902                                  0.589515
# LLFC CIRC PMP CURRENTGA2801-AI.PV                   0.177064
# LLFC CIRC PMP SPEEDGA2801-SI.PV                     0.262729
# Scrubber FanGB2801-AI                               0.138311
# HBF Vacuum PIC2917                                 -0.669092
# HBF CurrentFD2901-AI                                0.680237
# HBF SpeedFD2901-SI                                  0.620791
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                 0.106426
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                -0.010170
# CLOTH WASH PMP DISCH FLOWFI2909                     0.410237
# Cakewash flowFIC2908                                1.000000
# Strong wash flowFIC2906                             0.723283
# Return acid flowFIC2905                             0.507375
# Product acid flowFIC2904                            0.481824
# HBF Vacuum pump ampsGB2901-AI                       0.650986
# No 1 filtrate %P2O5                                 0.063201
# No 1 filtrate Sp Gr                                 0.092936
# No 1 filtrate FREEACID                              0.032145
# Gypsum TP2O5 loss                                   0.085014
#
#                                         Strong wash flowFIC2906  \
# Weigh feeder rate AJD2706A-WIC.PV                      0.132989
# Weigh feeder rate BJD2706B-WIC.PV                      0.125956
# Ball mill ampsPA2729A-AI                               0.059574
# BALL MILL VENT SYS TEMPTI2705.PV                       0.011027
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                 0.030765
# BAG FLTR SUC PRESSUREPI2705A.PV                       -0.004399
# FAN SUC PRESSUREPI2705C.PV                            -0.059892
# SCREW CONV - CURRENTJD2709-AI.PV                       0.224897
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                   -0.033998
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                    0.394869
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                    0.237130
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                   0.345590
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                   0.418508
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                 0.094008
# ATTACK AGTR A CURRENTGD2801A-AI.PV                     0.080332
# ATTACK AGTR B CURRENTGD2801B-AI.PV                     0.209496
# ATTACK AGTR C CURRENTGD2801C-AI.PV                     0.105015
# ATTACK AGTR D CURRENTGD2801D-AI.PV                     0.134259
# ATTACK RCT B TEMPTI2801B.PV                            0.244848
# ATTACK RCT D TEMPTI2801D.PV                            0.234861
# Filter SPGPA2_FILSPG                                   0.083586
# Slurry SPGPA2_SLURRYSPG                                0.087271
# Free AcidPA2_FREEACID                                 -0.081058
# Reactor SolidsREACT-SOLIDS.PV                          0.043812
# NEW DIGESTION TANK LEVELLI2802.PV                     -0.030741
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                 -0.296924
# TD LLFC I/L & O/L TEMPTDY2806.PV                       0.211143
# Slurry FlowFIC2902                                     0.659580
# LLFC CIRC PMP CURRENTGA2801-AI.PV                      0.078724
# LLFC CIRC PMP SPEEDGA2801-SI.PV                        0.299845
# Scrubber FanGB2801-AI                                  0.061907
# HBF Vacuum PIC2917                                    -0.631239
# HBF CurrentFD2901-AI                                   0.724526
# HBF SpeedFD2901-SI                                     0.667148
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                    0.184653
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                   -0.093362
# CLOTH WASH PMP DISCH FLOWFI2909                        0.462032
# Cakewash flowFIC2908                                   0.723283
# Strong wash flowFIC2906                                1.000000
# Return acid flowFIC2905                                0.583805
# Product acid flowFIC2904                               0.511709
# HBF Vacuum pump ampsGB2901-AI                          0.673883
# No 1 filtrate %P2O5                                    0.010576
# No 1 filtrate Sp Gr                                    0.012192
# No 1 filtrate FREEACID                                -0.032321
# Gypsum TP2O5 loss                                      0.017941
#
#                                         Return acid flowFIC2905  \
# Weigh feeder rate AJD2706A-WIC.PV                      0.100662
# Weigh feeder rate BJD2706B-WIC.PV                      0.096272
# Ball mill ampsPA2729A-AI                               0.064739
# BALL MILL VENT SYS TEMPTI2705.PV                       0.053883
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                 0.044852
# BAG FLTR SUC PRESSUREPI2705A.PV                        0.003638
# FAN SUC PRESSUREPI2705C.PV                            -0.065967
# SCREW CONV - CURRENTJD2709-AI.PV                       0.220501
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                   -0.034275
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                    0.335218
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                    0.210964
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                   0.339053
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                   0.355451
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                 0.144760
# ATTACK AGTR A CURRENTGD2801A-AI.PV                     0.160953
# ATTACK AGTR B CURRENTGD2801B-AI.PV                     0.122315
# ATTACK AGTR C CURRENTGD2801C-AI.PV                     0.100565
# ATTACK AGTR D CURRENTGD2801D-AI.PV                     0.091317
# ATTACK RCT B TEMPTI2801B.PV                            0.156822
# ATTACK RCT D TEMPTI2801D.PV                            0.162033
# Filter SPGPA2_FILSPG                                  -0.031869
# Slurry SPGPA2_SLURRYSPG                               -0.032908
# Free AcidPA2_FREEACID                                 -0.121217
# Reactor SolidsREACT-SOLIDS.PV                         -0.015318
# NEW DIGESTION TANK LEVELLI2802.PV                     -0.017452
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                 -0.207698
# TD LLFC I/L & O/L TEMPTDY2806.PV                       0.196624
# Slurry FlowFIC2902                                     0.631440
# LLFC CIRC PMP CURRENTGA2801-AI.PV                      0.113985
# LLFC CIRC PMP SPEEDGA2801-SI.PV                        0.299819
# Scrubber FanGB2801-AI                                  0.211827
# HBF Vacuum PIC2917                                    -0.609605
# HBF CurrentFD2901-AI                                   0.647092
# HBF SpeedFD2901-SI                                     0.595735
# ...
# CLOTH WASH PMP DISCH FLOWFI2909                         0.347126
# Cakewash flowFIC2908                                    0.481824
# Strong wash flowFIC2906                                 0.511709
# Return acid flowFIC2905                                 0.319143
# Product acid flowFIC2904                                1.000000
# HBF Vacuum pump ampsGB2901-AI                           0.476463
# No 1 filtrate %P2O5                                     0.011327
# No 1 filtrate Sp Gr                                    -0.001411
# No 1 filtrate FREEACID                                 -0.148241
# Gypsum TP2O5 loss                                      -0.016550
#
#                                         HBF Vacuum pump ampsGB2901-AI  \
# Weigh feeder rate AJD2706A-WIC.PV                            0.145271
# Weigh feeder rate BJD2706B-WIC.PV                            0.136833
# Ball mill ampsPA2729A-AI                                     0.095940
# BALL MILL VENT SYS TEMPTI2705.PV                             0.038135
# BALL MILL VENT FAN CURRENTGB2705-AI.PV                       0.066636
# BAG FLTR SUC PRESSUREPI2705A.PV                             -0.003501
# FAN SUC PRESSUREPI2705C.PV                                  -0.097121
# SCREW CONV - CURRENTJD2709-AI.PV                             0.325894
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                         -0.042008
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                          0.481503
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                          0.315582
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                         0.461516
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                         0.522107
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV                       0.074128
# ATTACK AGTR A CURRENTGD2801A-AI.PV                           0.136986
# ATTACK AGTR B CURRENTGD2801B-AI.PV                           0.168091
# ATTACK AGTR C CURRENTGD2801C-AI.PV                           0.056113
# ATTACK AGTR D CURRENTGD2801D-AI.PV                           0.092201
# ATTACK RCT B TEMPTI2801B.PV                                  0.307166
# ATTACK RCT D TEMPTI2801D.PV                                  0.296657
# Filter SPGPA2_FILSPG                                         0.011076
# Slurry SPGPA2_SLURRYSPG                                     -0.038286
# Free AcidPA2_FREEACID                                       -0.128811
# Reactor SolidsREACT-SOLIDS.PV                               -0.051932
# NEW DIGESTION TANK LEVELLI2802.PV                           -0.068285
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                       -0.365624
# TD LLFC I/L & O/L TEMPTDY2806.PV                             0.363287
# Slurry FlowFIC2902                                           0.790044
# LLFC CIRC PMP CURRENTGA2801-AI.PV                            0.170602
# LLFC CIRC PMP SPEEDGA2801-SI.PV                              0.408276
# Scrubber FanGB2801-AI                                        0.225222
# HBF Vacuum PIC2917                                          -0.821609
# HBF CurrentFD2901-AI                                         0.863909
# HBF SpeedFD2901-SI                                           0.790809
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                          0.230299
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                         -0.068408
# CLOTH WASH PMP DISCH FLOWFI2909                              0.691544
# Cakewash flowFIC2908                                         0.650986
# Strong wash flowFIC2906                                      0.673883
# Return acid flowFIC2905                                      0.627990
# Product acid flowFIC2904                                     0.476463
# HBF Vacuum pump ampsGB2901-AI                                1.000000
# No 1 filtrate %P2O5                                          0.117103
# No 1 filtrate Sp Gr                                          0.105719
# No 1 filtrate FREEACID                                       0.036333
# Gypsum TP2O5 loss                                            0.015640
#
#                                         No 1 filtrate %P2O5  \
# Weigh feeder rate AJD2706A-WIC.PV                  0.185335
# Weigh feeder rate BJD2706B-WIC.PV                  0.177790
# Ball mill ampsPA2729A-AI                           0.194315
# BALL MILL VENT SYS TEMPTI2705.PV                   0.092213
# BALL MILL VENT FAN CURRENTGB2705-AI.PV             0.094626
# BAG FLTR SUC PRESSUREPI2705A.PV                   -0.072981
# FAN SUC PRESSUREPI2705C.PV                        -0.133019
# SCREW CONV - CURRENTJD2709-AI.PV                   0.053327
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                0.054021
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                0.084911
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                0.019337
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV               0.032920
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV               0.065980
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV            -0.034389
# ATTACK AGTR A CURRENTGD2801A-AI.PV                -0.062042
# ATTACK AGTR B CURRENTGD2801B-AI.PV                 0.087452
# ATTACK AGTR C CURRENTGD2801C-AI.PV                -0.101545
# ATTACK AGTR D CURRENTGD2801D-AI.PV                -0.090249
# ATTACK RCT B TEMPTI2801B.PV                        0.237154
# ATTACK RCT D TEMPTI2801D.PV                        0.261427
# Filter SPGPA2_FILSPG                               0.175323
# Slurry SPGPA2_SLURRYSPG                            0.175240
# Free AcidPA2_FREEACID                              0.070880
# Reactor SolidsREACT-SOLIDS.PV                      0.082750
# NEW DIGESTION TANK LEVELLI2802.PV                 -0.059600
# LOW LVL FLASH COOLER VACUUMPIC2801.PV             -0.125371
# TD LLFC I/L & O/L TEMPTDY2806.PV                   0.007764
# Slurry FlowFIC2902                                 0.102312
# LLFC CIRC PMP CURRENTGA2801-AI.PV                  0.201207
# LLFC CIRC PMP SPEEDGA2801-SI.PV                    0.284614
# Scrubber FanGB2801-AI                              0.035802
# HBF Vacuum PIC2917                                -0.123520
# HBF CurrentFD2901-AI                               0.064932
# HBF SpeedFD2901-SI                                 0.148401
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                0.172676
# CLOTH TRACK BELLOW 2 PRESSUREPI2903               -0.204035
# CLOTH WASH PMP DISCH FLOWFI2909                   -0.089123
# Cakewash flowFIC2908                               0.063201
# Strong wash flowFIC2906                            0.010576
# Return acid flowFIC2905                            0.055841
# Product acid flowFIC2904                           0.011327
# HBF Vacuum pump ampsGB2901-AI                      0.117103
# No 1 filtrate %P2O5                                1.000000
# No 1 filtrate Sp Gr                                0.849867
# No 1 filtrate FREEACID                             0.003685
# Gypsum TP2O5 loss                                  0.116251
#
#                                         No 1 filtrate Sp Gr  \
# Weigh feeder rate AJD2706A-WIC.PV                  0.153333
# Weigh feeder rate BJD2706B-WIC.PV                  0.146527
# Ball mill ampsPA2729A-AI                           0.151320
# BALL MILL VENT SYS TEMPTI2705.PV                   0.050860
# BALL MILL VENT FAN CURRENTGB2705-AI.PV             0.076893
# BAG FLTR SUC PRESSUREPI2705A.PV                   -0.073577
# FAN SUC PRESSUREPI2705C.PV                        -0.109884
# SCREW CONV - CURRENTJD2709-AI.PV                   0.007744
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                0.125736
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                0.117877
# WEIGH FDR B FEED RATEJD2715B-WIC.PV               -0.061238
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV              -0.009795
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV               0.017742
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV            -0.137476
# ATTACK AGTR A CURRENTGD2801A-AI.PV                -0.072276
# ATTACK AGTR B CURRENTGD2801B-AI.PV                 0.126175
# ATTACK AGTR C CURRENTGD2801C-AI.PV                -0.077670
# ATTACK AGTR D CURRENTGD2801D-AI.PV                -0.063293
# ATTACK RCT B TEMPTI2801B.PV                        0.150412
# ATTACK RCT D TEMPTI2801D.PV                        0.169555
# Filter SPGPA2_FILSPG                               0.223426
# Slurry SPGPA2_SLURRYSPG                            0.163278
# Free AcidPA2_FREEACID                              0.116050
# Reactor SolidsREACT-SOLIDS.PV                      0.036445
# NEW DIGESTION TANK LEVELLI2802.PV                 -0.056524
# LOW LVL FLASH COOLER VACUUMPIC2801.PV             -0.032680
# TD LLFC I/L & O/L TEMPTDY2806.PV                  -0.019824
# Slurry FlowFIC2902                                 0.090523
# LLFC CIRC PMP CURRENTGA2801-AI.PV                  0.115078
# LLFC CIRC PMP SPEEDGA2801-SI.PV                    0.196105
# Scrubber FanGB2801-AI                             -0.048580
# HBF Vacuum PIC2917                                -0.107184
# HBF CurrentFD2901-AI                               0.053618
# HBF SpeedFD2901-SI                                 0.145057
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                0.068559
# CLOTH TRACK BELLOW 2 PRESSUREPI2903               -0.092024
# CLOTH WASH PMP DISCH FLOWFI2909                   -0.134759
# Cakewash flowFIC2908                               0.092936
# Strong wash flowFIC2906                            0.012192
# Return acid flowFIC2905                            0.032049
# Product acid flowFIC2904                          -0.001411
# HBF Vacuum pump ampsGB2901-AI                      0.105719
# No 1 filtrate %P2O5                                0.849867
# No 1 filtrate Sp Gr                                1.000000
# No 1 filtrate FREEACID                             0.167572
# Gypsum TP2O5 loss                                  0.190288
#
#                                         No 1 filtrate FREEACID  \
# Weigh feeder rate AJD2706A-WIC.PV                    -0.132818
# Weigh feeder rate BJD2706B-WIC.PV                    -0.115612
# Ball mill ampsPA2729A-AI                             -0.139574
# BALL MILL VENT SYS TEMPTI2705.PV                     -0.056210
# BALL MILL VENT FAN CURRENTGB2705-AI.PV               -0.062046
# BAG FLTR SUC PRESSUREPI2705A.PV                       0.088663
# FAN SUC PRESSUREPI2705C.PV                            0.076765
# SCREW CONV - CURRENTJD2709-AI.PV                      0.017064
# BUCKET ELEVATOR CURRENTJD2710-AI.PV                   0.046663
# WEIGH FDR A FEED RATEJD2715A-WIC.PV                  -0.054082
# WEIGH FDR B FEED RATEJD2715B-WIC.PV                  -0.008727
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV                 -0.161263
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV                  0.019152
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV               -0.434162
# ATTACK AGTR A CURRENTGD2801A-AI.PV                    0.065891
# ATTACK AGTR B CURRENTGD2801B-AI.PV                    0.032863
# ATTACK AGTR C CURRENTGD2801C-AI.PV                    0.096528
# ATTACK AGTR D CURRENTGD2801D-AI.PV                    0.091336
# ATTACK RCT B TEMPTI2801B.PV                          -0.127110
# ATTACK RCT D TEMPTI2801D.PV                          -0.125951
# Filter SPGPA2_FILSPG                                 -0.103970
# Slurry SPGPA2_SLURRYSPG                               0.015985
# Free AcidPA2_FREEACID                                 0.062888
# Reactor SolidsREACT-SOLIDS.PV                         0.086260
# NEW DIGESTION TANK LEVELLI2802.PV                     0.097290
# LOW LVL FLASH COOLER VACUUMPIC2801.PV                 0.167182
# TD LLFC I/L & O/L TEMPTDY2806.PV                     -0.029741
# Slurry FlowFIC2902                                    0.054344
# LLFC CIRC PMP CURRENTGA2801-AI.PV                    -0.041564
# LLFC CIRC PMP SPEEDGA2801-SI.PV                       0.003725
# Scrubber FanGB2801-AI                                 0.122096
# HBF Vacuum PIC2917                                   -0.088359
# HBF CurrentFD2901-AI                                  0.030249
# HBF SpeedFD2901-SI                                    0.031601
# CLOTH TRACK BELLOW 1 PRESSUREPI2902                   0.152899
# CLOTH TRACK BELLOW 2 PRESSUREPI2903                  -0.141886
# CLOTH WASH PMP DISCH FLOWFI2909                      -0.071943
# Cakewash flowFIC2908                                  0.032145
# Strong wash flowFIC2906                              -0.032321
# Return acid flowFIC2905                               0.000867
# Product acid flowFIC2904                             -0.148241
# HBF Vacuum pump ampsGB2901-AI                         0.036333
# No 1 filtrate %P2O5                                   0.003685
# No 1 filtrate Sp Gr                                   0.167572
# No 1 filtrate FREEACID                                1.000000
# Gypsum TP2O5 loss                                     0.034809
#
#                                         Gypsum TP2O5 loss
# Weigh feeder rate AJD2706A-WIC.PV                0.002204
# Weigh feeder rate BJD2706B-WIC.PV                0.003845
# Ball mill ampsPA2729A-AI                        -0.010459
# BALL MILL VENT SYS TEMPTI2705.PV                -0.024976
# BALL MILL VENT FAN CURRENTGB2705-AI.PV           0.019871
# BAG FLTR SUC PRESSUREPI2705A.PV                 -0.029518
# FAN SUC PRESSUREPI2705C.PV                      -0.014576
# SCREW CONV - CURRENTJD2709-AI.PV                 0.061637
# BUCKET ELEVATOR CURRENTJD2710-AI.PV              0.017481
# WEIGH FDR A FEED RATEJD2715A-WIC.PV             -0.107495
# WEIGH FDR B FEED RATEJD2715B-WIC.PV              0.038087
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV            -0.097222
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV             0.058865
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV          -0.199300
# ATTACK AGTR A CURRENTGD2801A-AI.PV               0.103129
# ATTACK AGTR B CURRENTGD2801B-AI.PV               0.096012
# ATTACK AGTR C CURRENTGD2801C-AI.PV               0.126257
# ATTACK AGTR D CURRENTGD2801D-AI.PV               0.068195
# ATTACK RCT B TEMPTI2801B.PV                      0.020478
# ATTACK RCT D TEMPTI2801D.PV                      0.029595
# Filter SPGPA2_FILSPG                             0.167853
# Slurry SPGPA2_SLURRYSPG                          0.109990
# Free AcidPA2_FREEACID                            0.042769
# Reactor SolidsREACT-SOLIDS.PV                    0.016504
# NEW DIGESTION TANK LEVELLI2802.PV                0.099643
# LOW LVL FLASH COOLER VACUUMPIC2801.PV            0.051084
# TD LLFC I/L & O/L TEMPTDY2806.PV                 0.000798
# Slurry FlowFIC2902                               0.036315
# LLFC CIRC PMP CURRENTGA2801-AI.PV                0.162667
# LLFC CIRC PMP SPEEDGA2801-SI.PV                  0.104624
# Scrubber FanGB2801-AI                            0.127386
# HBF Vacuum PIC2917                              -0.060366
# HBF CurrentFD2901-AI                             0.015336
# HBF SpeedFD2901-SI                               0.038883
# CLOTH TRACK BELLOW 1 PRESSUREPI2902              0.035619
# CLOTH TRACK BELLOW 2 PRESSUREPI2903             -0.020900
# CLOTH WASH PMP DISCH FLOWFI2909                  0.008398
# Cakewash flowFIC2908                             0.085014
# Strong wash flowFIC2906                          0.017941
# Return acid flowFIC2905                          0.027749
# Product acid flowFIC2904                        -0.016550
# HBF Vacuum pump ampsGB2901-AI                    0.015640
# No 1 filtrate %P2O5                              0.116251
# No 1 filtrate Sp Gr                              0.190288
# No 1 filtrate FREEACID                           0.034809
# Gypsum TP2O5 loss                                1.000000
#
# [46 rows x 46 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))

sns.heatmap(
    corr_matrix,
    cmap="coolwarm",
    annot=False
)

plt.title("Correlation Heatmap")

plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        
        corr_value = corr_matrix.iloc[i, j]

        if abs(corr_value) < 0.1:
            print(
                corr_matrix.columns[i],
                "<->",
                corr_matrix.columns[j],
                "=",
                round(corr_value,3)
            )
# Out:
# Weigh feeder rate AJD2706A-WIC.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = -0.069
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.039
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = -0.048
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = -0.027
# Weigh feeder rate AJD2706A-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.042
# Weigh feeder rate AJD2706A-WIC.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.042
# Weigh feeder rate AJD2706A-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.08
# Weigh feeder rate AJD2706A-WIC.PV <-> HBF Vacuum PIC2917 = -0.1
# Weigh feeder rate AJD2706A-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.085
# Weigh feeder rate AJD2706A-WIC.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.073
# Weigh feeder rate AJD2706A-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.025
# Weigh feeder rate AJD2706A-WIC.PV <-> Gypsum TP2O5 loss = 0.002
# Weigh feeder rate BJD2706B-WIC.PV <-> BALL MILL VENT SYS TEMPTI2705.PV = 0.077
# Weigh feeder rate BJD2706B-WIC.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = -0.07
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.034
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.096
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = -0.043
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = -0.024
# Weigh feeder rate BJD2706B-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.043
# Weigh feeder rate BJD2706B-WIC.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.044
# Weigh feeder rate BJD2706B-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.077
# Weigh feeder rate BJD2706B-WIC.PV <-> HBF Vacuum PIC2917 = -0.094
# Weigh feeder rate BJD2706B-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.074
# Weigh feeder rate BJD2706B-WIC.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.06
# Weigh feeder rate BJD2706B-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.029
# Weigh feeder rate BJD2706B-WIC.PV <-> Return acid flowFIC2905 = 0.096
# Weigh feeder rate BJD2706B-WIC.PV <-> Gypsum TP2O5 loss = 0.004
# Ball mill ampsPA2729A-AI <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.063
# Ball mill ampsPA2729A-AI <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.012
# Ball mill ampsPA2729A-AI <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.048
# Ball mill ampsPA2729A-AI <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = -0.018
# Ball mill ampsPA2729A-AI <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.01
# Ball mill ampsPA2729A-AI <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.043
# Ball mill ampsPA2729A-AI <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = -0.017
# Ball mill ampsPA2729A-AI <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = -0.005
# Ball mill ampsPA2729A-AI <-> Filter SPGPA2_FILSPG = 0.086
# Ball mill ampsPA2729A-AI <-> Slurry SPGPA2_SLURRYSPG = -0.015
# Ball mill ampsPA2729A-AI <-> Reactor SolidsREACT-SOLIDS.PV = -0.076
# Ball mill ampsPA2729A-AI <-> NEW DIGESTION TANK LEVELLI2802.PV = -0.029
# Ball mill ampsPA2729A-AI <-> Slurry FlowFIC2902 = 0.084
# Ball mill ampsPA2729A-AI <-> HBF Vacuum PIC2917 = -0.052
# Ball mill ampsPA2729A-AI <-> HBF CurrentFD2901-AI = 0.035
# Ball mill ampsPA2729A-AI <-> HBF SpeedFD2901-SI = 0.073
# Ball mill ampsPA2729A-AI <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.039
# Ball mill ampsPA2729A-AI <-> Cakewash flowFIC2908 = 0.063
# Ball mill ampsPA2729A-AI <-> Strong wash flowFIC2906 = 0.06
# Ball mill ampsPA2729A-AI <-> Return acid flowFIC2905 = 0.065
# Ball mill ampsPA2729A-AI <-> Product acid flowFIC2904 = 0.054
# Ball mill ampsPA2729A-AI <-> HBF Vacuum pump ampsGB2901-AI = 0.096
# Ball mill ampsPA2729A-AI <-> Gypsum TP2O5 loss = -0.01
# BALL MILL VENT SYS TEMPTI2705.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = -0.082
# BALL MILL VENT SYS TEMPTI2705.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = -0.095
# BALL MILL VENT SYS TEMPTI2705.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = -0.065
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.027
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = -0.044
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.006
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.01
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK RCT B TEMPTI2801B.PV = -0.095
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK RCT D TEMPTI2801D.PV = -0.055
# BALL MILL VENT SYS TEMPTI2705.PV <-> Filter SPGPA2_FILSPG = -0.071
# BALL MILL VENT SYS TEMPTI2705.PV <-> Slurry SPGPA2_SLURRYSPG = -0.098
# BALL MILL VENT SYS TEMPTI2705.PV <-> Free AcidPA2_FREEACID = 0.049
# BALL MILL VENT SYS TEMPTI2705.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.064
# BALL MILL VENT SYS TEMPTI2705.PV <-> Slurry FlowFIC2902 = 0.079
# BALL MILL VENT SYS TEMPTI2705.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.019
# BALL MILL VENT SYS TEMPTI2705.PV <-> Scrubber FanGB2801-AI = 0.007
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF Vacuum PIC2917 = -0.037
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF CurrentFD2901-AI = 0.019
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF SpeedFD2901-SI = 0.022
# BALL MILL VENT SYS TEMPTI2705.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.091
# BALL MILL VENT SYS TEMPTI2705.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.019
# BALL MILL VENT SYS TEMPTI2705.PV <-> Cakewash flowFIC2908 = 0.003
# BALL MILL VENT SYS TEMPTI2705.PV <-> Strong wash flowFIC2906 = 0.011
# BALL MILL VENT SYS TEMPTI2705.PV <-> Return acid flowFIC2905 = 0.054
# BALL MILL VENT SYS TEMPTI2705.PV <-> Product acid flowFIC2904 = -0.018
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.038
# BALL MILL VENT SYS TEMPTI2705.PV <-> No 1 filtrate %P2O5 = 0.092
# BALL MILL VENT SYS TEMPTI2705.PV <-> No 1 filtrate Sp Gr = 0.051
# BALL MILL VENT SYS TEMPTI2705.PV <-> No 1 filtrate FREEACID = -0.056
# BALL MILL VENT SYS TEMPTI2705.PV <-> Gypsum TP2O5 loss = -0.025
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.097
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.042
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.043
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.046
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.018
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.07
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.073
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.069
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.052
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.037
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Filter SPGPA2_FILSPG = 0.051
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Slurry SPGPA2_SLURRYSPG = -0.024
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.063
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = -0.076
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = -0.011
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Slurry FlowFIC2902 = 0.078
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.084
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Scrubber FanGB2801-AI = -0.038
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF Vacuum PIC2917 = -0.047
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF CurrentFD2901-AI = 0.05
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF SpeedFD2901-SI = 0.082
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.072
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.005
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Cakewash flowFIC2908 = 0.045
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Strong wash flowFIC2906 = 0.031
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Return acid flowFIC2905 = 0.045
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Product acid flowFIC2904 = 0.026
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.067
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> No 1 filtrate %P2O5 = 0.095
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> No 1 filtrate Sp Gr = 0.077
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> No 1 filtrate FREEACID = -0.062
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Gypsum TP2O5 loss = 0.02
# BAG FLTR SUC PRESSUREPI2705A.PV <-> SCREW CONV - CURRENTJD2709-AI.PV = -0.041
# BAG FLTR SUC PRESSUREPI2705A.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.017
# BAG FLTR SUC PRESSUREPI2705A.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = -0.008
# BAG FLTR SUC PRESSUREPI2705A.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.048
# BAG FLTR SUC PRESSUREPI2705A.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.001
# BAG FLTR SUC PRESSUREPI2705A.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.055
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.011
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = -0.014
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.015
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = -0.021
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK RCT B TEMPTI2801B.PV = -0.092
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Filter SPGPA2_FILSPG = -0.08
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Slurry SPGPA2_SLURRYSPG = -0.0
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.054
# BAG FLTR SUC PRESSUREPI2705A.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.034
# BAG FLTR SUC PRESSUREPI2705A.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.073
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Slurry FlowFIC2902 = 0.007
# BAG FLTR SUC PRESSUREPI2705A.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = -0.015
# BAG FLTR SUC PRESSUREPI2705A.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = -0.096
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Scrubber FanGB2801-AI = 0.092
# BAG FLTR SUC PRESSUREPI2705A.PV <-> HBF Vacuum PIC2917 = -0.023
# BAG FLTR SUC PRESSUREPI2705A.PV <-> HBF CurrentFD2901-AI = 0.006
# BAG FLTR SUC PRESSUREPI2705A.PV <-> HBF SpeedFD2901-SI = -0.013
# BAG FLTR SUC PRESSUREPI2705A.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = -0.032
# BAG FLTR SUC PRESSUREPI2705A.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.013
# BAG FLTR SUC PRESSUREPI2705A.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.006
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Cakewash flowFIC2908 = -0.033
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Strong wash flowFIC2906 = -0.004
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Return acid flowFIC2905 = 0.004
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Product acid flowFIC2904 = -0.051
# BAG FLTR SUC PRESSUREPI2705A.PV <-> HBF Vacuum pump ampsGB2901-AI = -0.004
# BAG FLTR SUC PRESSUREPI2705A.PV <-> No 1 filtrate %P2O5 = -0.073
# BAG FLTR SUC PRESSUREPI2705A.PV <-> No 1 filtrate Sp Gr = -0.074
# BAG FLTR SUC PRESSUREPI2705A.PV <-> No 1 filtrate FREEACID = 0.089
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Gypsum TP2O5 loss = -0.03
# FAN SUC PRESSUREPI2705C.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = -0.095
# FAN SUC PRESSUREPI2705C.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = -0.085
# FAN SUC PRESSUREPI2705C.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = -0.067
# FAN SUC PRESSUREPI2705C.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = -0.048
# FAN SUC PRESSUREPI2705C.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = -0.097
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.016
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = -0.075
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.001
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.002
# FAN SUC PRESSUREPI2705C.PV <-> Filter SPGPA2_FILSPG = -0.069
# FAN SUC PRESSUREPI2705C.PV <-> Slurry SPGPA2_SLURRYSPG = 0.017
# FAN SUC PRESSUREPI2705C.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.067
# FAN SUC PRESSUREPI2705C.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.076
# FAN SUC PRESSUREPI2705C.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = -0.003
# FAN SUC PRESSUREPI2705C.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = -0.085
# FAN SUC PRESSUREPI2705C.PV <-> Scrubber FanGB2801-AI = 0.059
# FAN SUC PRESSUREPI2705C.PV <-> HBF Vacuum PIC2917 = 0.068
# FAN SUC PRESSUREPI2705C.PV <-> HBF CurrentFD2901-AI = -0.067
# FAN SUC PRESSUREPI2705C.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.088
# FAN SUC PRESSUREPI2705C.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.005
# FAN SUC PRESSUREPI2705C.PV <-> Cakewash flowFIC2908 = -0.059
# FAN SUC PRESSUREPI2705C.PV <-> Strong wash flowFIC2906 = -0.06
# FAN SUC PRESSUREPI2705C.PV <-> Return acid flowFIC2905 = -0.066
# FAN SUC PRESSUREPI2705C.PV <-> Product acid flowFIC2904 = -0.057
# FAN SUC PRESSUREPI2705C.PV <-> HBF Vacuum pump ampsGB2901-AI = -0.097
# FAN SUC PRESSUREPI2705C.PV <-> No 1 filtrate FREEACID = 0.077
# FAN SUC PRESSUREPI2705C.PV <-> Gypsum TP2O5 loss = -0.015
# SCREW CONV - CURRENTJD2709-AI.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = -0.039
# SCREW CONV - CURRENTJD2709-AI.PV <-> Filter SPGPA2_FILSPG = -0.055
# SCREW CONV - CURRENTJD2709-AI.PV <-> Slurry SPGPA2_SLURRYSPG = -0.051
# SCREW CONV - CURRENTJD2709-AI.PV <-> Free AcidPA2_FREEACID = -0.024
# SCREW CONV - CURRENTJD2709-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.022
# SCREW CONV - CURRENTJD2709-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.095
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate %P2O5 = 0.053
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate Sp Gr = 0.008
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate FREEACID = 0.017
# SCREW CONV - CURRENTJD2709-AI.PV <-> Gypsum TP2O5 loss = 0.062
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.049
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.025
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.046
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.032
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = -0.025
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = -0.014
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Filter SPGPA2_FILSPG = -0.032
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Slurry SPGPA2_SLURRYSPG = -0.024
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.004
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Slurry FlowFIC2902 = -0.016
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.023
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Scrubber FanGB2801-AI = 0.027
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF Vacuum PIC2917 = 0.014
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF CurrentFD2901-AI = -0.054
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF SpeedFD2901-SI = 0.021
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.081
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.05
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.056
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Cakewash flowFIC2908 = -0.049
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Strong wash flowFIC2906 = -0.034
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Return acid flowFIC2905 = -0.034
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Product acid flowFIC2904 = -0.057
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = -0.042
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> No 1 filtrate %P2O5 = 0.054
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> No 1 filtrate FREEACID = 0.047
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Gypsum TP2O5 loss = 0.017
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.032
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.028
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.087
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Filter SPGPA2_FILSPG = 0.018
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = -0.05
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Free AcidPA2_FREEACID = -0.049
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.069
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Scrubber FanGB2801-AI = -0.079
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.042
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> No 1 filtrate %P2O5 = 0.085
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> No 1 filtrate FREEACID = -0.054
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = -0.034
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.079
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.018
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Filter SPGPA2_FILSPG = 0.068
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.026
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Free AcidPA2_FREEACID = 0.007
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.017
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = -0.026
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> No 1 filtrate %P2O5 = 0.019
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> No 1 filtrate Sp Gr = -0.061
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> No 1 filtrate FREEACID = -0.009
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Gypsum TP2O5 loss = 0.038
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = -0.052
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.094
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = -0.1
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Filter SPGPA2_FILSPG = 0.024
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Scrubber FanGB2801-AI = -0.013
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.042
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.071
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> No 1 filtrate %P2O5 = 0.033
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> No 1 filtrate Sp Gr = -0.01
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Gypsum TP2O5 loss = -0.097
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Filter SPGPA2_FILSPG = 0.019
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Slurry SPGPA2_SLURRYSPG = -0.019
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Reactor SolidsREACT-SOLIDS.PV = -0.035
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.03
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate %P2O5 = 0.066
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate Sp Gr = 0.018
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate FREEACID = 0.019
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Gypsum TP2O5 loss = 0.059
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Filter SPGPA2_FILSPG = 0.035
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Free AcidPA2_FREEACID = -0.058
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = -0.043
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Slurry FlowFIC2902 = -0.005
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.094
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF Vacuum PIC2917 = 0.003
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF CurrentFD2901-AI = 0.06
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF SpeedFD2901-SI = 0.041
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Cakewash flowFIC2908 = 0.076
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Strong wash flowFIC2906 = 0.094
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.074
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> No 1 filtrate %P2O5 = -0.034
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Filter SPGPA2_FILSPG = 0.016
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Free AcidPA2_FREEACID = 0.013
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.028
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = -0.052
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Slurry FlowFIC2902 = 0.089
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.092
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.014
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Strong wash flowFIC2906 = 0.08
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> No 1 filtrate %P2O5 = -0.062
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> No 1 filtrate Sp Gr = -0.072
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> No 1 filtrate FREEACID = 0.066
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Free AcidPA2_FREEACID = 0.063
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.054
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.024
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Scrubber FanGB2801-AI = -0.031
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.044
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Product acid flowFIC2904 = 0.05
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> No 1 filtrate %P2O5 = 0.087
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> No 1 filtrate FREEACID = 0.033
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Gypsum TP2O5 loss = 0.096
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Filter SPGPA2_FILSPG = 0.032
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Free AcidPA2_FREEACID = 0.049
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.091
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = -0.055
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Slurry FlowFIC2902 = 0.05
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.096
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Scrubber FanGB2801-AI = 0.099
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF Vacuum PIC2917 = -0.08
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF CurrentFD2901-AI = 0.093
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF SpeedFD2901-SI = 0.066
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.033
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.056
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> No 1 filtrate Sp Gr = -0.078
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> No 1 filtrate FREEACID = 0.097
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Filter SPGPA2_FILSPG = 0.017
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Slurry SPGPA2_SLURRYSPG = 0.072
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Free AcidPA2_FREEACID = 0.027
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.07
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.042
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = -0.073
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.078
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Slurry FlowFIC2902 = 0.078
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = -0.025
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Scrubber FanGB2801-AI = 0.011
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF Vacuum PIC2917 = -0.054
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF SpeedFD2901-SI = 0.082
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.015
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Return acid flowFIC2905 = 0.091
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Product acid flowFIC2904 = -0.028
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.092
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> No 1 filtrate %P2O5 = -0.09
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> No 1 filtrate Sp Gr = -0.063
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> No 1 filtrate FREEACID = 0.091
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Gypsum TP2O5 loss = 0.068
# ATTACK RCT B TEMPTI2801B.PV <-> Free AcidPA2_FREEACID = 0.058
# ATTACK RCT B TEMPTI2801B.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.013
# ATTACK RCT B TEMPTI2801B.PV <-> Scrubber FanGB2801-AI = -0.064
# ATTACK RCT B TEMPTI2801B.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.083
# ATTACK RCT B TEMPTI2801B.PV <-> Gypsum TP2O5 loss = 0.02
# ATTACK RCT D TEMPTI2801D.PV <-> Free AcidPA2_FREEACID = 0.065
# ATTACK RCT D TEMPTI2801D.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.018
# ATTACK RCT D TEMPTI2801D.PV <-> Scrubber FanGB2801-AI = -0.045
# ATTACK RCT D TEMPTI2801D.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.077
# ATTACK RCT D TEMPTI2801D.PV <-> Gypsum TP2O5 loss = 0.03
# Filter SPGPA2_FILSPG <-> TD LLFC I/L & O/L TEMPTDY2806.PV = -0.06
# Filter SPGPA2_FILSPG <-> Slurry FlowFIC2902 = -0.055
# Filter SPGPA2_FILSPG <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.074
# Filter SPGPA2_FILSPG <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = -0.057
# Filter SPGPA2_FILSPG <-> Scrubber FanGB2801-AI = -0.065
# Filter SPGPA2_FILSPG <-> HBF Vacuum PIC2917 = -0.095
# Filter SPGPA2_FILSPG <-> HBF CurrentFD2901-AI = -0.006
# Filter SPGPA2_FILSPG <-> HBF SpeedFD2901-SI = 0.087
# Filter SPGPA2_FILSPG <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.068
# Filter SPGPA2_FILSPG <-> Strong wash flowFIC2906 = 0.084
# Filter SPGPA2_FILSPG <-> Return acid flowFIC2905 = -0.032
# Filter SPGPA2_FILSPG <-> HBF Vacuum pump ampsGB2901-AI = 0.011
# Slurry SPGPA2_SLURRYSPG <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = -0.062
# Slurry SPGPA2_SLURRYSPG <-> Scrubber FanGB2801-AI = -0.041
# Slurry SPGPA2_SLURRYSPG <-> HBF Vacuum PIC2917 = -0.073
# Slurry SPGPA2_SLURRYSPG <-> HBF CurrentFD2901-AI = -0.031
# Slurry SPGPA2_SLURRYSPG <-> HBF SpeedFD2901-SI = 0.019
# Slurry SPGPA2_SLURRYSPG <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.072
# Slurry SPGPA2_SLURRYSPG <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.1
# Slurry SPGPA2_SLURRYSPG <-> Strong wash flowFIC2906 = 0.087
# Slurry SPGPA2_SLURRYSPG <-> Return acid flowFIC2905 = -0.033
# Slurry SPGPA2_SLURRYSPG <-> Product acid flowFIC2904 = 0.045
# Slurry SPGPA2_SLURRYSPG <-> HBF Vacuum pump ampsGB2901-AI = -0.038
# Slurry SPGPA2_SLURRYSPG <-> No 1 filtrate FREEACID = 0.016
# Free AcidPA2_FREEACID <-> Reactor SolidsREACT-SOLIDS.PV = 0.032
# Free AcidPA2_FREEACID <-> NEW DIGESTION TANK LEVELLI2802.PV = -0.024
# Free AcidPA2_FREEACID <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.01
# Free AcidPA2_FREEACID <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.058
# Free AcidPA2_FREEACID <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = -0.056
# Free AcidPA2_FREEACID <-> Scrubber FanGB2801-AI = -0.08
# Free AcidPA2_FREEACID <-> HBF SpeedFD2901-SI = -0.07
# Free AcidPA2_FREEACID <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = -0.012
# Free AcidPA2_FREEACID <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.012
# Free AcidPA2_FREEACID <-> Cakewash flowFIC2908 = 0.008
# Free AcidPA2_FREEACID <-> Strong wash flowFIC2906 = -0.081
# Free AcidPA2_FREEACID <-> Product acid flowFIC2904 = -0.049
# Free AcidPA2_FREEACID <-> No 1 filtrate %P2O5 = 0.071
# Free AcidPA2_FREEACID <-> No 1 filtrate FREEACID = 0.063
# Free AcidPA2_FREEACID <-> Gypsum TP2O5 loss = 0.043
# Reactor SolidsREACT-SOLIDS.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.001
# Reactor SolidsREACT-SOLIDS.PV <-> Scrubber FanGB2801-AI = -0.002
# Reactor SolidsREACT-SOLIDS.PV <-> HBF Vacuum PIC2917 = -0.019
# Reactor SolidsREACT-SOLIDS.PV <-> HBF CurrentFD2901-AI = -0.032
# Reactor SolidsREACT-SOLIDS.PV <-> HBF SpeedFD2901-SI = -0.036
# Reactor SolidsREACT-SOLIDS.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.04
# Reactor SolidsREACT-SOLIDS.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.07
# Reactor SolidsREACT-SOLIDS.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.068
# Reactor SolidsREACT-SOLIDS.PV <-> Strong wash flowFIC2906 = 0.044
# Reactor SolidsREACT-SOLIDS.PV <-> Return acid flowFIC2905 = -0.015
# Reactor SolidsREACT-SOLIDS.PV <-> Product acid flowFIC2904 = -0.035
# Reactor SolidsREACT-SOLIDS.PV <-> HBF Vacuum pump ampsGB2901-AI = -0.052
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate %P2O5 = 0.083
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate Sp Gr = 0.036
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate FREEACID = 0.086
# Reactor SolidsREACT-SOLIDS.PV <-> Gypsum TP2O5 loss = 0.017
# NEW DIGESTION TANK LEVELLI2802.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = -0.083
# NEW DIGESTION TANK LEVELLI2802.PV <-> Slurry FlowFIC2902 = 0.055
# NEW DIGESTION TANK LEVELLI2802.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = -0.08
# NEW DIGESTION TANK LEVELLI2802.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.092
# NEW DIGESTION TANK LEVELLI2802.PV <-> Scrubber FanGB2801-AI = 0.021
# NEW DIGESTION TANK LEVELLI2802.PV <-> HBF Vacuum PIC2917 = 0.017
# NEW DIGESTION TANK LEVELLI2802.PV <-> HBF CurrentFD2901-AI = -0.076
# NEW DIGESTION TANK LEVELLI2802.PV <-> HBF SpeedFD2901-SI = -0.035
# NEW DIGESTION TANK LEVELLI2802.PV <-> Strong wash flowFIC2906 = -0.031
# NEW DIGESTION TANK LEVELLI2802.PV <-> Return acid flowFIC2905 = -0.017
# NEW DIGESTION TANK LEVELLI2802.PV <-> Product acid flowFIC2904 = -0.088
# NEW DIGESTION TANK LEVELLI2802.PV <-> HBF Vacuum pump ampsGB2901-AI = -0.068
# NEW DIGESTION TANK LEVELLI2802.PV <-> No 1 filtrate %P2O5 = -0.06
# NEW DIGESTION TANK LEVELLI2802.PV <-> No 1 filtrate Sp Gr = -0.057
# NEW DIGESTION TANK LEVELLI2802.PV <-> No 1 filtrate FREEACID = 0.097
# NEW DIGESTION TANK LEVELLI2802.PV <-> Gypsum TP2O5 loss = 0.1
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> No 1 filtrate Sp Gr = -0.033
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> Gypsum TP2O5 loss = 0.051
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.08
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> No 1 filtrate %P2O5 = 0.008
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> No 1 filtrate Sp Gr = -0.02
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> No 1 filtrate FREEACID = -0.03
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Gypsum TP2O5 loss = 0.001
# Slurry FlowFIC2902 <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.087
# Slurry FlowFIC2902 <-> No 1 filtrate Sp Gr = 0.091
# Slurry FlowFIC2902 <-> No 1 filtrate FREEACID = 0.054
# Slurry FlowFIC2902 <-> Gypsum TP2O5 loss = 0.036
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.007
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Strong wash flowFIC2906 = 0.079
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Product acid flowFIC2904 = 0.048
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> No 1 filtrate FREEACID = -0.042
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> No 1 filtrate FREEACID = 0.004
# Scrubber FanGB2801-AI <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = -0.075
# Scrubber FanGB2801-AI <-> Strong wash flowFIC2906 = 0.062
# Scrubber FanGB2801-AI <-> Product acid flowFIC2904 = -0.036
# Scrubber FanGB2801-AI <-> No 1 filtrate %P2O5 = 0.036
# Scrubber FanGB2801-AI <-> No 1 filtrate Sp Gr = -0.049
# HBF Vacuum PIC2917 <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.014
# HBF Vacuum PIC2917 <-> No 1 filtrate FREEACID = -0.088
# HBF Vacuum PIC2917 <-> Gypsum TP2O5 loss = -0.06
# HBF CurrentFD2901-AI <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.051
# HBF CurrentFD2901-AI <-> No 1 filtrate %P2O5 = 0.065
# HBF CurrentFD2901-AI <-> No 1 filtrate Sp Gr = 0.054
# HBF CurrentFD2901-AI <-> No 1 filtrate FREEACID = 0.03
# HBF CurrentFD2901-AI <-> Gypsum TP2O5 loss = 0.015
# HBF SpeedFD2901-SI <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = -0.026
# HBF SpeedFD2901-SI <-> No 1 filtrate FREEACID = 0.032
# HBF SpeedFD2901-SI <-> Gypsum TP2O5 loss = 0.039
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> CLOTH WASH PMP DISCH FLOWFI2909 = -0.058
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Product acid flowFIC2904 = 0.062
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> No 1 filtrate Sp Gr = 0.069
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Gypsum TP2O5 loss = 0.036
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Cakewash flowFIC2908 = -0.01
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Strong wash flowFIC2906 = -0.093
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Return acid flowFIC2905 = -0.016
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Product acid flowFIC2904 = 0.007
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> HBF Vacuum pump ampsGB2901-AI = -0.068
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> No 1 filtrate Sp Gr = -0.092
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Gypsum TP2O5 loss = -0.021
# CLOTH WASH PMP DISCH FLOWFI2909 <-> No 1 filtrate %P2O5 = -0.089
# CLOTH WASH PMP DISCH FLOWFI2909 <-> No 1 filtrate FREEACID = -0.072
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Gypsum TP2O5 loss = 0.008
# Cakewash flowFIC2908 <-> No 1 filtrate %P2O5 = 0.063
# Cakewash flowFIC2908 <-> No 1 filtrate Sp Gr = 0.093
# Cakewash flowFIC2908 <-> No 1 filtrate FREEACID = 0.032
# Cakewash flowFIC2908 <-> Gypsum TP2O5 loss = 0.085
# Strong wash flowFIC2906 <-> No 1 filtrate %P2O5 = 0.011
# Strong wash flowFIC2906 <-> No 1 filtrate Sp Gr = 0.012
# Strong wash flowFIC2906 <-> No 1 filtrate FREEACID = -0.032
# Strong wash flowFIC2906 <-> Gypsum TP2O5 loss = 0.018
# Return acid flowFIC2905 <-> No 1 filtrate %P2O5 = 0.056
# Return acid flowFIC2905 <-> No 1 filtrate Sp Gr = 0.032
# Return acid flowFIC2905 <-> No 1 filtrate FREEACID = 0.001
# Return acid flowFIC2905 <-> Gypsum TP2O5 loss = 0.028
# Product acid flowFIC2904 <-> No 1 filtrate %P2O5 = 0.011
# Product acid flowFIC2904 <-> No 1 filtrate Sp Gr = -0.001
# Product acid flowFIC2904 <-> Gypsum TP2O5 loss = -0.017
# HBF Vacuum pump ampsGB2901-AI <-> No 1 filtrate FREEACID = 0.036
# HBF Vacuum pump ampsGB2901-AI <-> Gypsum TP2O5 loss = 0.016
# No 1 filtrate %P2O5 <-> No 1 filtrate FREEACID = 0.004
# No 1 filtrate FREEACID <-> Gypsum TP2O5 loss = 0.035

# %%
corr_matrix = df.corr(numeric_only=True)

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):

        corr_value = corr_matrix.iloc[i, j]

        if corr_value > 0:   # Positive correlation

            print(
                corr_matrix.columns[i],
                "<->",
                corr_matrix.columns[j],
                "=",
                round(corr_value, 3)
            )
# Out:
# Weigh feeder rate AJD2706A-WIC.PV <-> Weigh feeder rate BJD2706B-WIC.PV = 0.971
# Weigh feeder rate AJD2706A-WIC.PV <-> Ball mill ampsPA2729A-AI = 0.54
# Weigh feeder rate AJD2706A-WIC.PV <-> BALL MILL VENT SYS TEMPTI2705.PV = 0.106
# Weigh feeder rate AJD2706A-WIC.PV <-> BALL MILL VENT FAN CURRENTGB2705-AI.PV = 0.729
# Weigh feeder rate AJD2706A-WIC.PV <-> SCREW CONV - CURRENTJD2709-AI.PV = 0.184
# Weigh feeder rate AJD2706A-WIC.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.214
# Weigh feeder rate AJD2706A-WIC.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.134
# Weigh feeder rate AJD2706A-WIC.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.265
# Weigh feeder rate AJD2706A-WIC.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.131
# Weigh feeder rate AJD2706A-WIC.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.254
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.103
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.432
# Weigh feeder rate AJD2706A-WIC.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.44
# Weigh feeder rate AJD2706A-WIC.PV <-> Filter SPGPA2_FILSPG = 0.132
# Weigh feeder rate AJD2706A-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.042
# Weigh feeder rate AJD2706A-WIC.PV <-> Free AcidPA2_FREEACID = 0.183
# Weigh feeder rate AJD2706A-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.08
# Weigh feeder rate AJD2706A-WIC.PV <-> Slurry FlowFIC2902 = 0.129
# Weigh feeder rate AJD2706A-WIC.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.133
# Weigh feeder rate AJD2706A-WIC.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.267
# Weigh feeder rate AJD2706A-WIC.PV <-> HBF CurrentFD2901-AI = 0.106
# Weigh feeder rate AJD2706A-WIC.PV <-> HBF SpeedFD2901-SI = 0.156
# Weigh feeder rate AJD2706A-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.085
# Weigh feeder rate AJD2706A-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.025
# Weigh feeder rate AJD2706A-WIC.PV <-> Cakewash flowFIC2908 = 0.138
# Weigh feeder rate AJD2706A-WIC.PV <-> Strong wash flowFIC2906 = 0.133
# Weigh feeder rate AJD2706A-WIC.PV <-> Return acid flowFIC2905 = 0.101
# Weigh feeder rate AJD2706A-WIC.PV <-> Product acid flowFIC2904 = 0.156
# Weigh feeder rate AJD2706A-WIC.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.145
# Weigh feeder rate AJD2706A-WIC.PV <-> No 1 filtrate %P2O5 = 0.185
# Weigh feeder rate AJD2706A-WIC.PV <-> No 1 filtrate Sp Gr = 0.153
# Weigh feeder rate AJD2706A-WIC.PV <-> Gypsum TP2O5 loss = 0.002
# Weigh feeder rate BJD2706B-WIC.PV <-> Ball mill ampsPA2729A-AI = 0.514
# Weigh feeder rate BJD2706B-WIC.PV <-> BALL MILL VENT SYS TEMPTI2705.PV = 0.077
# Weigh feeder rate BJD2706B-WIC.PV <-> BALL MILL VENT FAN CURRENTGB2705-AI.PV = 0.715
# Weigh feeder rate BJD2706B-WIC.PV <-> SCREW CONV - CURRENTJD2709-AI.PV = 0.187
# Weigh feeder rate BJD2706B-WIC.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.206
# Weigh feeder rate BJD2706B-WIC.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.13
# Weigh feeder rate BJD2706B-WIC.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.261
# Weigh feeder rate BJD2706B-WIC.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.122
# Weigh feeder rate BJD2706B-WIC.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.236
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.096
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.414
# Weigh feeder rate BJD2706B-WIC.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.419
# Weigh feeder rate BJD2706B-WIC.PV <-> Filter SPGPA2_FILSPG = 0.136
# Weigh feeder rate BJD2706B-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.043
# Weigh feeder rate BJD2706B-WIC.PV <-> Free AcidPA2_FREEACID = 0.183
# Weigh feeder rate BJD2706B-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.077
# Weigh feeder rate BJD2706B-WIC.PV <-> Slurry FlowFIC2902 = 0.124
# Weigh feeder rate BJD2706B-WIC.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.13
# Weigh feeder rate BJD2706B-WIC.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.258
# Weigh feeder rate BJD2706B-WIC.PV <-> HBF CurrentFD2901-AI = 0.101
# Weigh feeder rate BJD2706B-WIC.PV <-> HBF SpeedFD2901-SI = 0.152
# Weigh feeder rate BJD2706B-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.074
# Weigh feeder rate BJD2706B-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.029
# Weigh feeder rate BJD2706B-WIC.PV <-> Cakewash flowFIC2908 = 0.132
# Weigh feeder rate BJD2706B-WIC.PV <-> Strong wash flowFIC2906 = 0.126
# Weigh feeder rate BJD2706B-WIC.PV <-> Return acid flowFIC2905 = 0.096
# Weigh feeder rate BJD2706B-WIC.PV <-> Product acid flowFIC2904 = 0.149
# Weigh feeder rate BJD2706B-WIC.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.137
# Weigh feeder rate BJD2706B-WIC.PV <-> No 1 filtrate %P2O5 = 0.178
# Weigh feeder rate BJD2706B-WIC.PV <-> No 1 filtrate Sp Gr = 0.147
# Weigh feeder rate BJD2706B-WIC.PV <-> Gypsum TP2O5 loss = 0.004
# Ball mill ampsPA2729A-AI <-> BALL MILL VENT SYS TEMPTI2705.PV = 0.648
# Ball mill ampsPA2729A-AI <-> BALL MILL VENT FAN CURRENTGB2705-AI.PV = 0.644
# Ball mill ampsPA2729A-AI <-> SCREW CONV - CURRENTJD2709-AI.PV = 0.303
# Ball mill ampsPA2729A-AI <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.158
# Ball mill ampsPA2729A-AI <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.063
# Ball mill ampsPA2729A-AI <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.012
# Ball mill ampsPA2729A-AI <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.048
# Ball mill ampsPA2729A-AI <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.129
# Ball mill ampsPA2729A-AI <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.043
# Ball mill ampsPA2729A-AI <-> ATTACK RCT B TEMPTI2801B.PV = 0.285
# Ball mill ampsPA2729A-AI <-> ATTACK RCT D TEMPTI2801D.PV = 0.319
# Ball mill ampsPA2729A-AI <-> Filter SPGPA2_FILSPG = 0.086
# Ball mill ampsPA2729A-AI <-> Free AcidPA2_FREEACID = 0.223
# Ball mill ampsPA2729A-AI <-> Slurry FlowFIC2902 = 0.084
# Ball mill ampsPA2729A-AI <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.127
# Ball mill ampsPA2729A-AI <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.337
# Ball mill ampsPA2729A-AI <-> HBF CurrentFD2901-AI = 0.035
# Ball mill ampsPA2729A-AI <-> HBF SpeedFD2901-SI = 0.073
# Ball mill ampsPA2729A-AI <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.154
# Ball mill ampsPA2729A-AI <-> Cakewash flowFIC2908 = 0.063
# Ball mill ampsPA2729A-AI <-> Strong wash flowFIC2906 = 0.06
# Ball mill ampsPA2729A-AI <-> Return acid flowFIC2905 = 0.065
# Ball mill ampsPA2729A-AI <-> Product acid flowFIC2904 = 0.054
# Ball mill ampsPA2729A-AI <-> HBF Vacuum pump ampsGB2901-AI = 0.096
# Ball mill ampsPA2729A-AI <-> No 1 filtrate %P2O5 = 0.194
# Ball mill ampsPA2729A-AI <-> No 1 filtrate Sp Gr = 0.151
# BALL MILL VENT SYS TEMPTI2705.PV <-> BALL MILL VENT FAN CURRENTGB2705-AI.PV = 0.384
# BALL MILL VENT SYS TEMPTI2705.PV <-> SCREW CONV - CURRENTJD2709-AI.PV = 0.196
# BALL MILL VENT SYS TEMPTI2705.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.207
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.027
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.006
# BALL MILL VENT SYS TEMPTI2705.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.01
# BALL MILL VENT SYS TEMPTI2705.PV <-> Free AcidPA2_FREEACID = 0.049
# BALL MILL VENT SYS TEMPTI2705.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.154
# BALL MILL VENT SYS TEMPTI2705.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.162
# BALL MILL VENT SYS TEMPTI2705.PV <-> Slurry FlowFIC2902 = 0.079
# BALL MILL VENT SYS TEMPTI2705.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.019
# BALL MILL VENT SYS TEMPTI2705.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.24
# BALL MILL VENT SYS TEMPTI2705.PV <-> Scrubber FanGB2801-AI = 0.007
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF CurrentFD2901-AI = 0.019
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF SpeedFD2901-SI = 0.022
# BALL MILL VENT SYS TEMPTI2705.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.128
# BALL MILL VENT SYS TEMPTI2705.PV <-> Cakewash flowFIC2908 = 0.003
# BALL MILL VENT SYS TEMPTI2705.PV <-> Strong wash flowFIC2906 = 0.011
# BALL MILL VENT SYS TEMPTI2705.PV <-> Return acid flowFIC2905 = 0.054
# BALL MILL VENT SYS TEMPTI2705.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.038
# BALL MILL VENT SYS TEMPTI2705.PV <-> No 1 filtrate %P2O5 = 0.092
# BALL MILL VENT SYS TEMPTI2705.PV <-> No 1 filtrate Sp Gr = 0.051
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> SCREW CONV - CURRENTJD2709-AI.PV = 0.214
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.097
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.042
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.043
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.046
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.018
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.07
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.073
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.069
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.052
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.037
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.236
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.256
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Filter SPGPA2_FILSPG = 0.051
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Free AcidPA2_FREEACID = 0.173
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Slurry FlowFIC2902 = 0.078
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.084
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.258
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF CurrentFD2901-AI = 0.05
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF SpeedFD2901-SI = 0.082
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.125
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.005
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Cakewash flowFIC2908 = 0.045
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Strong wash flowFIC2906 = 0.031
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Return acid flowFIC2905 = 0.045
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Product acid flowFIC2904 = 0.026
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.067
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> No 1 filtrate %P2O5 = 0.095
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> No 1 filtrate Sp Gr = 0.077
# BALL MILL VENT FAN CURRENTGB2705-AI.PV <-> Gypsum TP2O5 loss = 0.02
# BAG FLTR SUC PRESSUREPI2705A.PV <-> FAN SUC PRESSUREPI2705C.PV = 0.299
# BAG FLTR SUC PRESSUREPI2705A.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.017
# BAG FLTR SUC PRESSUREPI2705A.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.048
# BAG FLTR SUC PRESSUREPI2705A.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.001
# BAG FLTR SUC PRESSUREPI2705A.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.055
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.011
# BAG FLTR SUC PRESSUREPI2705A.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.015
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.054
# BAG FLTR SUC PRESSUREPI2705A.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.106
# BAG FLTR SUC PRESSUREPI2705A.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.034
# BAG FLTR SUC PRESSUREPI2705A.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.073
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Slurry FlowFIC2902 = 0.007
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Scrubber FanGB2801-AI = 0.092
# BAG FLTR SUC PRESSUREPI2705A.PV <-> HBF CurrentFD2901-AI = 0.006
# BAG FLTR SUC PRESSUREPI2705A.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.013
# BAG FLTR SUC PRESSUREPI2705A.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.006
# BAG FLTR SUC PRESSUREPI2705A.PV <-> Return acid flowFIC2905 = 0.004
# BAG FLTR SUC PRESSUREPI2705A.PV <-> No 1 filtrate FREEACID = 0.089
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.001
# FAN SUC PRESSUREPI2705C.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.002
# FAN SUC PRESSUREPI2705C.PV <-> Slurry SPGPA2_SLURRYSPG = 0.017
# FAN SUC PRESSUREPI2705C.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.067
# FAN SUC PRESSUREPI2705C.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.076
# FAN SUC PRESSUREPI2705C.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.246
# FAN SUC PRESSUREPI2705C.PV <-> Scrubber FanGB2801-AI = 0.059
# FAN SUC PRESSUREPI2705C.PV <-> HBF Vacuum PIC2917 = 0.068
# FAN SUC PRESSUREPI2705C.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.088
# FAN SUC PRESSUREPI2705C.PV <-> No 1 filtrate FREEACID = 0.077
# SCREW CONV - CURRENTJD2709-AI.PV <-> BUCKET ELEVATOR CURRENTJD2710-AI.PV = 0.259
# SCREW CONV - CURRENTJD2709-AI.PV <-> WEIGH FDR A FEED RATEJD2715A-WIC.PV = 0.15
# SCREW CONV - CURRENTJD2709-AI.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.109
# SCREW CONV - CURRENTJD2709-AI.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.128
# SCREW CONV - CURRENTJD2709-AI.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.184
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.245
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.172
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.223
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.172
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.258
# SCREW CONV - CURRENTJD2709-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.259
# SCREW CONV - CURRENTJD2709-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.095
# SCREW CONV - CURRENTJD2709-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.2
# SCREW CONV - CURRENTJD2709-AI.PV <-> Slurry FlowFIC2902 = 0.226
# SCREW CONV - CURRENTJD2709-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.333
# SCREW CONV - CURRENTJD2709-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.637
# SCREW CONV - CURRENTJD2709-AI.PV <-> Scrubber FanGB2801-AI = 0.106
# SCREW CONV - CURRENTJD2709-AI.PV <-> HBF CurrentFD2901-AI = 0.278
# SCREW CONV - CURRENTJD2709-AI.PV <-> HBF SpeedFD2901-SI = 0.232
# SCREW CONV - CURRENTJD2709-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.387
# SCREW CONV - CURRENTJD2709-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.228
# SCREW CONV - CURRENTJD2709-AI.PV <-> Cakewash flowFIC2908 = 0.226
# SCREW CONV - CURRENTJD2709-AI.PV <-> Strong wash flowFIC2906 = 0.225
# SCREW CONV - CURRENTJD2709-AI.PV <-> Return acid flowFIC2905 = 0.221
# SCREW CONV - CURRENTJD2709-AI.PV <-> Product acid flowFIC2904 = 0.11
# SCREW CONV - CURRENTJD2709-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.326
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate %P2O5 = 0.053
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate Sp Gr = 0.008
# SCREW CONV - CURRENTJD2709-AI.PV <-> No 1 filtrate FREEACID = 0.017
# SCREW CONV - CURRENTJD2709-AI.PV <-> Gypsum TP2O5 loss = 0.062
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.049
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.025
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.046
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.032
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Free AcidPA2_FREEACID = 0.13
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.219
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.124
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.023
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.175
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Scrubber FanGB2801-AI = 0.027
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF Vacuum PIC2917 = 0.014
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> HBF SpeedFD2901-SI = 0.021
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.081
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> No 1 filtrate %P2O5 = 0.054
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> No 1 filtrate Sp Gr = 0.126
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> No 1 filtrate FREEACID = 0.047
# BUCKET ELEVATOR CURRENTJD2710-AI.PV <-> Gypsum TP2O5 loss = 0.017
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> WEIGH FDR B FEED RATEJD2715B-WIC.PV = 0.164
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.655
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.511
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.24
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.201
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.028
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.087
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.334
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.315
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Filter SPGPA2_FILSPG = 0.018
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.261
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Slurry FlowFIC2902 = 0.397
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.127
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.322
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> HBF CurrentFD2901-AI = 0.429
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> HBF SpeedFD2901-SI = 0.394
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.101
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.344
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Cakewash flowFIC2908 = 0.361
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Strong wash flowFIC2906 = 0.395
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Return acid flowFIC2905 = 0.335
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> Product acid flowFIC2904 = 0.329
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.482
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> No 1 filtrate %P2O5 = 0.085
# WEIGH FDR A FEED RATEJD2715A-WIC.PV <-> No 1 filtrate Sp Gr = 0.118
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> H2SO4 TO ATTACK RCT A FLOWFIC2802.PV = 0.43
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.604
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.201
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.181
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.079
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.018
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.324
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.305
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Filter SPGPA2_FILSPG = 0.068
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Slurry SPGPA2_SLURRYSPG = 0.026
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Free AcidPA2_FREEACID = 0.007
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.407
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Slurry FlowFIC2902 = 0.266
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.256
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.112
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Scrubber FanGB2801-AI = 0.253
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> HBF CurrentFD2901-AI = 0.305
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> HBF SpeedFD2901-SI = 0.316
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.17
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.242
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Cakewash flowFIC2908 = 0.269
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Strong wash flowFIC2906 = 0.237
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Return acid flowFIC2905 = 0.211
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Product acid flowFIC2904 = 0.164
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.316
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> No 1 filtrate %P2O5 = 0.019
# WEIGH FDR B FEED RATEJD2715B-WIC.PV <-> Gypsum TP2O5 loss = 0.038
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> H2SO4 TO ATTACK RCT B FLOWFIC2803.PV = 0.606
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> RECYCL ACD ATTACK RCT A FLOWFIC2804.PV = 0.419
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.094
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.479
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.457
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Filter SPGPA2_FILSPG = 0.024
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.491
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Slurry FlowFIC2902 = 0.381
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.362
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.273
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> HBF CurrentFD2901-AI = 0.409
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> HBF SpeedFD2901-SI = 0.372
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.042
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.071
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.424
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Cakewash flowFIC2908 = 0.334
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Strong wash flowFIC2906 = 0.346
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Return acid flowFIC2905 = 0.339
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> Product acid flowFIC2904 = 0.375
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.462
# H2SO4 TO ATTACK RCT A FLOWFIC2802.PV <-> No 1 filtrate %P2O5 = 0.033
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK AGTR A CURRENTGD2801A-AI.PV = 0.238
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.293
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.18
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.144
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.384
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.348
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Filter SPGPA2_FILSPG = 0.019
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.03
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.545
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Slurry FlowFIC2902 = 0.443
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.206
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.26
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Scrubber FanGB2801-AI = 0.227
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> HBF CurrentFD2901-AI = 0.488
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> HBF SpeedFD2901-SI = 0.486
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.295
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.312
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Cakewash flowFIC2908 = 0.414
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Strong wash flowFIC2906 = 0.419
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Return acid flowFIC2905 = 0.355
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Product acid flowFIC2904 = 0.255
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.522
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate %P2O5 = 0.066
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate Sp Gr = 0.018
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> No 1 filtrate FREEACID = 0.019
# H2SO4 TO ATTACK RCT B FLOWFIC2803.PV <-> Gypsum TP2O5 loss = 0.059
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.261
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.256
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Filter SPGPA2_FILSPG = 0.035
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Slurry SPGPA2_SLURRYSPG = 0.157
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.156
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.119
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.094
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF Vacuum PIC2917 = 0.003
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF CurrentFD2901-AI = 0.06
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF SpeedFD2901-SI = 0.041
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.211
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.235
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Cakewash flowFIC2908 = 0.076
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Strong wash flowFIC2906 = 0.094
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Return acid flowFIC2905 = 0.145
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> Product acid flowFIC2904 = 0.303
# RECYCL ACD ATTACK RCT A FLOWFIC2804.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.074
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> ATTACK AGTR B CURRENTGD2801B-AI.PV = 0.292
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.535
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.349
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.111
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.121
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Filter SPGPA2_FILSPG = 0.016
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Slurry SPGPA2_SLURRYSPG = 0.131
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Free AcidPA2_FREEACID = 0.013
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.14
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.028
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.248
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Slurry FlowFIC2902 = 0.089
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.271
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.092
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Scrubber FanGB2801-AI = 0.375
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> HBF CurrentFD2901-AI = 0.172
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> HBF SpeedFD2901-SI = 0.155
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.112
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.014
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.151
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Cakewash flowFIC2908 = 0.174
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Strong wash flowFIC2906 = 0.08
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Return acid flowFIC2905 = 0.161
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.137
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> No 1 filtrate FREEACID = 0.066
# ATTACK AGTR A CURRENTGD2801A-AI.PV <-> Gypsum TP2O5 loss = 0.103
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> ATTACK AGTR C CURRENTGD2801C-AI.PV = 0.414
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.328
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.335
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.323
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Filter SPGPA2_FILSPG = 0.146
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Slurry SPGPA2_SLURRYSPG = 0.134
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Free AcidPA2_FREEACID = 0.063
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.054
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.024
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.207
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Slurry FlowFIC2902 = 0.13
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.145
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.223
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> HBF CurrentFD2901-AI = 0.147
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> HBF SpeedFD2901-SI = 0.142
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.211
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Cakewash flowFIC2908 = 0.221
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Strong wash flowFIC2906 = 0.209
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Return acid flowFIC2905 = 0.122
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Product acid flowFIC2904 = 0.05
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.168
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> No 1 filtrate %P2O5 = 0.087
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> No 1 filtrate Sp Gr = 0.126
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> No 1 filtrate FREEACID = 0.033
# ATTACK AGTR B CURRENTGD2801B-AI.PV <-> Gypsum TP2O5 loss = 0.096
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> ATTACK AGTR D CURRENTGD2801D-AI.PV = 0.478
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.134
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.132
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Filter SPGPA2_FILSPG = 0.032
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Slurry SPGPA2_SLURRYSPG = 0.126
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Free AcidPA2_FREEACID = 0.049
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.122
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.091
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.152
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Slurry FlowFIC2902 = 0.05
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.15
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.096
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Scrubber FanGB2801-AI = 0.099
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF CurrentFD2901-AI = 0.093
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF SpeedFD2901-SI = 0.066
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.228
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Cakewash flowFIC2908 = 0.141
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Strong wash flowFIC2906 = 0.105
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Return acid flowFIC2905 = 0.101
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.056
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> No 1 filtrate FREEACID = 0.097
# ATTACK AGTR C CURRENTGD2801C-AI.PV <-> Gypsum TP2O5 loss = 0.126
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> ATTACK RCT B TEMPTI2801B.PV = 0.141
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.137
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Filter SPGPA2_FILSPG = 0.017
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Slurry SPGPA2_SLURRYSPG = 0.072
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Free AcidPA2_FREEACID = 0.027
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.07
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> NEW DIGESTION TANK LEVELLI2802.PV = 0.042
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.078
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Slurry FlowFIC2902 = 0.078
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.132
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Scrubber FanGB2801-AI = 0.011
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF CurrentFD2901-AI = 0.104
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF SpeedFD2901-SI = 0.082
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.193
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Cakewash flowFIC2908 = 0.128
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Strong wash flowFIC2906 = 0.134
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Return acid flowFIC2905 = 0.091
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.092
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> No 1 filtrate FREEACID = 0.091
# ATTACK AGTR D CURRENTGD2801D-AI.PV <-> Gypsum TP2O5 loss = 0.068
# ATTACK RCT B TEMPTI2801B.PV <-> ATTACK RCT D TEMPTI2801D.PV = 0.993
# ATTACK RCT B TEMPTI2801B.PV <-> Filter SPGPA2_FILSPG = 0.204
# ATTACK RCT B TEMPTI2801B.PV <-> Slurry SPGPA2_SLURRYSPG = 0.134
# ATTACK RCT B TEMPTI2801B.PV <-> Free AcidPA2_FREEACID = 0.058
# ATTACK RCT B TEMPTI2801B.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.013
# ATTACK RCT B TEMPTI2801B.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.426
# ATTACK RCT B TEMPTI2801B.PV <-> Slurry FlowFIC2902 = 0.219
# ATTACK RCT B TEMPTI2801B.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.437
# ATTACK RCT B TEMPTI2801B.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.502
# ATTACK RCT B TEMPTI2801B.PV <-> HBF CurrentFD2901-AI = 0.208
# ATTACK RCT B TEMPTI2801B.PV <-> HBF SpeedFD2901-SI = 0.284
# ATTACK RCT B TEMPTI2801B.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.252
# ATTACK RCT B TEMPTI2801B.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.083
# ATTACK RCT B TEMPTI2801B.PV <-> Cakewash flowFIC2908 = 0.282
# ATTACK RCT B TEMPTI2801B.PV <-> Strong wash flowFIC2906 = 0.245
# ATTACK RCT B TEMPTI2801B.PV <-> Return acid flowFIC2905 = 0.157
# ATTACK RCT B TEMPTI2801B.PV <-> Product acid flowFIC2904 = 0.263
# ATTACK RCT B TEMPTI2801B.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.307
# ATTACK RCT B TEMPTI2801B.PV <-> No 1 filtrate %P2O5 = 0.237
# ATTACK RCT B TEMPTI2801B.PV <-> No 1 filtrate Sp Gr = 0.15
# ATTACK RCT B TEMPTI2801B.PV <-> Gypsum TP2O5 loss = 0.02
# ATTACK RCT D TEMPTI2801D.PV <-> Filter SPGPA2_FILSPG = 0.213
# ATTACK RCT D TEMPTI2801D.PV <-> Slurry SPGPA2_SLURRYSPG = 0.143
# ATTACK RCT D TEMPTI2801D.PV <-> Free AcidPA2_FREEACID = 0.065
# ATTACK RCT D TEMPTI2801D.PV <-> Reactor SolidsREACT-SOLIDS.PV = 0.018
# ATTACK RCT D TEMPTI2801D.PV <-> TD LLFC I/L & O/L TEMPTDY2806.PV = 0.364
# ATTACK RCT D TEMPTI2801D.PV <-> Slurry FlowFIC2902 = 0.22
# ATTACK RCT D TEMPTI2801D.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.447
# ATTACK RCT D TEMPTI2801D.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.519
# ATTACK RCT D TEMPTI2801D.PV <-> HBF CurrentFD2901-AI = 0.204
# ATTACK RCT D TEMPTI2801D.PV <-> HBF SpeedFD2901-SI = 0.281
# ATTACK RCT D TEMPTI2801D.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.239
# ATTACK RCT D TEMPTI2801D.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.077
# ATTACK RCT D TEMPTI2801D.PV <-> Cakewash flowFIC2908 = 0.281
# ATTACK RCT D TEMPTI2801D.PV <-> Strong wash flowFIC2906 = 0.235
# ATTACK RCT D TEMPTI2801D.PV <-> Return acid flowFIC2905 = 0.162
# ATTACK RCT D TEMPTI2801D.PV <-> Product acid flowFIC2904 = 0.256
# ATTACK RCT D TEMPTI2801D.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.297
# ATTACK RCT D TEMPTI2801D.PV <-> No 1 filtrate %P2O5 = 0.261
# ATTACK RCT D TEMPTI2801D.PV <-> No 1 filtrate Sp Gr = 0.17
# ATTACK RCT D TEMPTI2801D.PV <-> Gypsum TP2O5 loss = 0.03
# Filter SPGPA2_FILSPG <-> Slurry SPGPA2_SLURRYSPG = 0.495
# Filter SPGPA2_FILSPG <-> Free AcidPA2_FREEACID = 0.244
# Filter SPGPA2_FILSPG <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.074
# Filter SPGPA2_FILSPG <-> HBF SpeedFD2901-SI = 0.087
# Filter SPGPA2_FILSPG <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.229
# Filter SPGPA2_FILSPG <-> Cakewash flowFIC2908 = 0.266
# Filter SPGPA2_FILSPG <-> Strong wash flowFIC2906 = 0.084
# Filter SPGPA2_FILSPG <-> Product acid flowFIC2904 = 0.128
# Filter SPGPA2_FILSPG <-> HBF Vacuum pump ampsGB2901-AI = 0.011
# Filter SPGPA2_FILSPG <-> No 1 filtrate %P2O5 = 0.175
# Filter SPGPA2_FILSPG <-> No 1 filtrate Sp Gr = 0.223
# Filter SPGPA2_FILSPG <-> Gypsum TP2O5 loss = 0.168
# Slurry SPGPA2_SLURRYSPG <-> Free AcidPA2_FREEACID = 0.171
# Slurry SPGPA2_SLURRYSPG <-> Reactor SolidsREACT-SOLIDS.PV = 0.811
# Slurry SPGPA2_SLURRYSPG <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.149
# Slurry SPGPA2_SLURRYSPG <-> HBF SpeedFD2901-SI = 0.019
# Slurry SPGPA2_SLURRYSPG <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.072
# Slurry SPGPA2_SLURRYSPG <-> Cakewash flowFIC2908 = 0.27
# Slurry SPGPA2_SLURRYSPG <-> Strong wash flowFIC2906 = 0.087
# Slurry SPGPA2_SLURRYSPG <-> Product acid flowFIC2904 = 0.045
# Slurry SPGPA2_SLURRYSPG <-> No 1 filtrate %P2O5 = 0.175
# Slurry SPGPA2_SLURRYSPG <-> No 1 filtrate Sp Gr = 0.163
# Slurry SPGPA2_SLURRYSPG <-> No 1 filtrate FREEACID = 0.016
# Slurry SPGPA2_SLURRYSPG <-> Gypsum TP2O5 loss = 0.11
# Free AcidPA2_FREEACID <-> Reactor SolidsREACT-SOLIDS.PV = 0.032
# Free AcidPA2_FREEACID <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.01
# Free AcidPA2_FREEACID <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.058
# Free AcidPA2_FREEACID <-> HBF Vacuum PIC2917 = 0.144
# Free AcidPA2_FREEACID <-> Cakewash flowFIC2908 = 0.008
# Free AcidPA2_FREEACID <-> No 1 filtrate %P2O5 = 0.071
# Free AcidPA2_FREEACID <-> No 1 filtrate Sp Gr = 0.116
# Free AcidPA2_FREEACID <-> No 1 filtrate FREEACID = 0.063
# Free AcidPA2_FREEACID <-> Gypsum TP2O5 loss = 0.043
# Reactor SolidsREACT-SOLIDS.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.001
# Reactor SolidsREACT-SOLIDS.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.118
# Reactor SolidsREACT-SOLIDS.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.04
# Reactor SolidsREACT-SOLIDS.PV <-> Cakewash flowFIC2908 = 0.131
# Reactor SolidsREACT-SOLIDS.PV <-> Strong wash flowFIC2906 = 0.044
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate %P2O5 = 0.083
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate Sp Gr = 0.036
# Reactor SolidsREACT-SOLIDS.PV <-> No 1 filtrate FREEACID = 0.086
# Reactor SolidsREACT-SOLIDS.PV <-> Gypsum TP2O5 loss = 0.017
# NEW DIGESTION TANK LEVELLI2802.PV <-> LOW LVL FLASH COOLER VACUUMPIC2801.PV = 0.114
# NEW DIGESTION TANK LEVELLI2802.PV <-> Slurry FlowFIC2902 = 0.055
# NEW DIGESTION TANK LEVELLI2802.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.092
# NEW DIGESTION TANK LEVELLI2802.PV <-> Scrubber FanGB2801-AI = 0.021
# NEW DIGESTION TANK LEVELLI2802.PV <-> HBF Vacuum PIC2917 = 0.017
# NEW DIGESTION TANK LEVELLI2802.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.22
# NEW DIGESTION TANK LEVELLI2802.PV <-> No 1 filtrate FREEACID = 0.097
# NEW DIGESTION TANK LEVELLI2802.PV <-> Gypsum TP2O5 loss = 0.1
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> Scrubber FanGB2801-AI = 0.101
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> HBF Vacuum PIC2917 = 0.238
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.174
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> No 1 filtrate FREEACID = 0.167
# LOW LVL FLASH COOLER VACUUMPIC2801.PV <-> Gypsum TP2O5 loss = 0.051
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Slurry FlowFIC2902 = 0.251
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.279
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.132
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Scrubber FanGB2801-AI = 0.167
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> HBF CurrentFD2901-AI = 0.313
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> HBF SpeedFD2901-SI = 0.229
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.181
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.281
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Cakewash flowFIC2908 = 0.212
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Strong wash flowFIC2906 = 0.211
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Return acid flowFIC2905 = 0.197
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Product acid flowFIC2904 = 0.121
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.363
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> No 1 filtrate %P2O5 = 0.008
# TD LLFC I/L & O/L TEMPTDY2806.PV <-> Gypsum TP2O5 loss = 0.001
# Slurry FlowFIC2902 <-> LLFC CIRC PMP CURRENTGA2801-AI.PV = 0.087
# Slurry FlowFIC2902 <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.363
# Slurry FlowFIC2902 <-> Scrubber FanGB2801-AI = 0.209
# Slurry FlowFIC2902 <-> HBF CurrentFD2901-AI = 0.864
# Slurry FlowFIC2902 <-> HBF SpeedFD2901-SI = 0.778
# Slurry FlowFIC2902 <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.27
# Slurry FlowFIC2902 <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.537
# Slurry FlowFIC2902 <-> Cakewash flowFIC2908 = 0.59
# Slurry FlowFIC2902 <-> Strong wash flowFIC2906 = 0.66
# Slurry FlowFIC2902 <-> Return acid flowFIC2905 = 0.631
# Slurry FlowFIC2902 <-> Product acid flowFIC2904 = 0.467
# Slurry FlowFIC2902 <-> HBF Vacuum pump ampsGB2901-AI = 0.79
# Slurry FlowFIC2902 <-> No 1 filtrate %P2O5 = 0.102
# Slurry FlowFIC2902 <-> No 1 filtrate Sp Gr = 0.091
# Slurry FlowFIC2902 <-> No 1 filtrate FREEACID = 0.054
# Slurry FlowFIC2902 <-> Gypsum TP2O5 loss = 0.036
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> LLFC CIRC PMP SPEEDGA2801-SI.PV = 0.332
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Scrubber FanGB2801-AI = 0.156
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> HBF CurrentFD2901-AI = 0.159
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> HBF SpeedFD2901-SI = 0.163
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.136
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.007
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.168
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Cakewash flowFIC2908 = 0.177
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Strong wash flowFIC2906 = 0.079
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Return acid flowFIC2905 = 0.114
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Product acid flowFIC2904 = 0.048
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.171
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> No 1 filtrate %P2O5 = 0.201
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> No 1 filtrate Sp Gr = 0.115
# LLFC CIRC PMP CURRENTGA2801-AI.PV <-> Gypsum TP2O5 loss = 0.163
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Scrubber FanGB2801-AI = 0.141
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> HBF CurrentFD2901-AI = 0.321
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> HBF SpeedFD2901-SI = 0.345
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.341
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.239
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Cakewash flowFIC2908 = 0.263
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Strong wash flowFIC2906 = 0.3
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Return acid flowFIC2905 = 0.3
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Product acid flowFIC2904 = 0.257
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> HBF Vacuum pump ampsGB2901-AI = 0.408
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> No 1 filtrate %P2O5 = 0.285
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> No 1 filtrate Sp Gr = 0.196
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> No 1 filtrate FREEACID = 0.004
# LLFC CIRC PMP SPEEDGA2801-SI.PV <-> Gypsum TP2O5 loss = 0.105
# Scrubber FanGB2801-AI <-> HBF CurrentFD2901-AI = 0.284
# Scrubber FanGB2801-AI <-> HBF SpeedFD2901-SI = 0.25
# Scrubber FanGB2801-AI <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.159
# Scrubber FanGB2801-AI <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.417
# Scrubber FanGB2801-AI <-> Cakewash flowFIC2908 = 0.138
# Scrubber FanGB2801-AI <-> Strong wash flowFIC2906 = 0.062
# Scrubber FanGB2801-AI <-> Return acid flowFIC2905 = 0.212
# Scrubber FanGB2801-AI <-> HBF Vacuum pump ampsGB2901-AI = 0.225
# Scrubber FanGB2801-AI <-> No 1 filtrate %P2O5 = 0.036
# Scrubber FanGB2801-AI <-> No 1 filtrate FREEACID = 0.122
# Scrubber FanGB2801-AI <-> Gypsum TP2O5 loss = 0.127
# HBF Vacuum PIC2917 <-> CLOTH TRACK BELLOW 2 PRESSUREPI2903 = 0.014
# HBF CurrentFD2901-AI <-> HBF SpeedFD2901-SI = 0.883
# HBF CurrentFD2901-AI <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.213
# HBF CurrentFD2901-AI <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.714
# HBF CurrentFD2901-AI <-> Cakewash flowFIC2908 = 0.68
# HBF CurrentFD2901-AI <-> Strong wash flowFIC2906 = 0.725
# HBF CurrentFD2901-AI <-> Return acid flowFIC2905 = 0.647
# HBF CurrentFD2901-AI <-> Product acid flowFIC2904 = 0.46
# HBF CurrentFD2901-AI <-> HBF Vacuum pump ampsGB2901-AI = 0.864
# HBF CurrentFD2901-AI <-> No 1 filtrate %P2O5 = 0.065
# HBF CurrentFD2901-AI <-> No 1 filtrate Sp Gr = 0.054
# HBF CurrentFD2901-AI <-> No 1 filtrate FREEACID = 0.03
# HBF CurrentFD2901-AI <-> Gypsum TP2O5 loss = 0.015
# HBF SpeedFD2901-SI <-> CLOTH TRACK BELLOW 1 PRESSUREPI2902 = 0.169
# HBF SpeedFD2901-SI <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.676
# HBF SpeedFD2901-SI <-> Cakewash flowFIC2908 = 0.621
# HBF SpeedFD2901-SI <-> Strong wash flowFIC2906 = 0.667
# HBF SpeedFD2901-SI <-> Return acid flowFIC2905 = 0.596
# HBF SpeedFD2901-SI <-> Product acid flowFIC2904 = 0.413
# HBF SpeedFD2901-SI <-> HBF Vacuum pump ampsGB2901-AI = 0.791
# HBF SpeedFD2901-SI <-> No 1 filtrate %P2O5 = 0.148
# HBF SpeedFD2901-SI <-> No 1 filtrate Sp Gr = 0.145
# HBF SpeedFD2901-SI <-> No 1 filtrate FREEACID = 0.032
# HBF SpeedFD2901-SI <-> Gypsum TP2O5 loss = 0.039
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Cakewash flowFIC2908 = 0.106
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Strong wash flowFIC2906 = 0.185
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Return acid flowFIC2905 = 0.111
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Product acid flowFIC2904 = 0.062
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> HBF Vacuum pump ampsGB2901-AI = 0.23
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> No 1 filtrate %P2O5 = 0.173
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> No 1 filtrate Sp Gr = 0.069
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> No 1 filtrate FREEACID = 0.153
# CLOTH TRACK BELLOW 1 PRESSUREPI2902 <-> Gypsum TP2O5 loss = 0.036
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> CLOTH WASH PMP DISCH FLOWFI2909 = 0.279
# CLOTH TRACK BELLOW 2 PRESSUREPI2903 <-> Product acid flowFIC2904 = 0.007
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Cakewash flowFIC2908 = 0.41
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Strong wash flowFIC2906 = 0.462
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Return acid flowFIC2905 = 0.506
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Product acid flowFIC2904 = 0.347
# CLOTH WASH PMP DISCH FLOWFI2909 <-> HBF Vacuum pump ampsGB2901-AI = 0.692
# CLOTH WASH PMP DISCH FLOWFI2909 <-> Gypsum TP2O5 loss = 0.008
# Cakewash flowFIC2908 <-> Strong wash flowFIC2906 = 0.723
# Cakewash flowFIC2908 <-> Return acid flowFIC2905 = 0.507
# Cakewash flowFIC2908 <-> Product acid flowFIC2904 = 0.482
# Cakewash flowFIC2908 <-> HBF Vacuum pump ampsGB2901-AI = 0.651
# Cakewash flowFIC2908 <-> No 1 filtrate %P2O5 = 0.063
# Cakewash flowFIC2908 <-> No 1 filtrate Sp Gr = 0.093
# Cakewash flowFIC2908 <-> No 1 filtrate FREEACID = 0.032
# Cakewash flowFIC2908 <-> Gypsum TP2O5 loss = 0.085
# Strong wash flowFIC2906 <-> Return acid flowFIC2905 = 0.584
# Strong wash flowFIC2906 <-> Product acid flowFIC2904 = 0.512
# Strong wash flowFIC2906 <-> HBF Vacuum pump ampsGB2901-AI = 0.674
# Strong wash flowFIC2906 <-> No 1 filtrate %P2O5 = 0.011
# Strong wash flowFIC2906 <-> No 1 filtrate Sp Gr = 0.012
# Strong wash flowFIC2906 <-> Gypsum TP2O5 loss = 0.018
# Return acid flowFIC2905 <-> Product acid flowFIC2904 = 0.319
# Return acid flowFIC2905 <-> HBF Vacuum pump ampsGB2901-AI = 0.628
# Return acid flowFIC2905 <-> No 1 filtrate %P2O5 = 0.056
# Return acid flowFIC2905 <-> No 1 filtrate Sp Gr = 0.032
# Return acid flowFIC2905 <-> No 1 filtrate FREEACID = 0.001
# Return acid flowFIC2905 <-> Gypsum TP2O5 loss = 0.028
# Product acid flowFIC2904 <-> HBF Vacuum pump ampsGB2901-AI = 0.476
# Product acid flowFIC2904 <-> No 1 filtrate %P2O5 = 0.011
# HBF Vacuum pump ampsGB2901-AI <-> No 1 filtrate %P2O5 = 0.117
# HBF Vacuum pump ampsGB2901-AI <-> No 1 filtrate Sp Gr = 0.106
# HBF Vacuum pump ampsGB2901-AI <-> No 1 filtrate FREEACID = 0.036
# HBF Vacuum pump ampsGB2901-AI <-> Gypsum TP2O5 loss = 0.016
# No 1 filtrate %P2O5 <-> No 1 filtrate Sp Gr = 0.85
# No 1 filtrate %P2O5 <-> No 1 filtrate FREEACID = 0.004
# No 1 filtrate %P2O5 <-> Gypsum TP2O5 loss = 0.116
# No 1 filtrate Sp Gr <-> No 1 filtrate FREEACID = 0.168
# No 1 filtrate Sp Gr <-> Gypsum TP2O5 loss = 0.19
# No 1 filtrate FREEACID <-> Gypsum TP2O5 loss = 0.035
